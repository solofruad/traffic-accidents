# %% [markdown]
# # 3 Exploration
# ### By **Néstor Suat** in 2020
#
# **Descripción:** Exploración de cada uno de los dataset resultado de accidentes.
#
# **Input:**
# * **1_server_bogota.tsv** -- 2,9 GB -- # 4’027.313 Tweets
# * **2_server_token_search.tsv** -- 119.4 MB -- # 271.153 Tweets
# * **3_server_token_user.tsv** -- 43.8 MB -- # 100.618 Tweets
# * **4_server_follow_timeline_user.tsv** -- 246.2 MB -- # 574.816 Tweets
#
# **Output:**
# * Undefined
# ***

# %%
import pandas as pd

# %%
filename = 'accident_3_server_token_user.tsv'
dir_ = '../../../data/database/output_ml/M1/'

# %%
df = pd.read_csv(dir_+filename, delimiter = "\t", quoting = 3 ) # Part1
del df['Unnamed: 0']

# %%
df.shape
# Out:
# (50111, 25)

# %%
count_tweet_by_username = df['user_name'].value_counts() # Show distribution of tweets by user
count_tweet_by_username[0:40]
# Out:
# BogotaTransito    44186
# WazeTrafficBOG    2407
# RedapBogota       2165
# Citytv            784
# CIVICOSBOG        569
# Name: user_name, dtype: int64

# %%
export = df[df['user_name'] == 'BogotaTransito'][['id_tweet','text','created_at','user_name','user_location']]

# %%
count_tweet_by_username = export['user_name'].value_counts() # Show distribution of tweets by user
count_tweet_by_username[0:40]
# Out:
# BogotaTransito    44186
# Name: user_name, dtype: int64

# %%
export.shape
# Out:
# (44186, 5)

# %%
export = df[['id_tweet','text','created_at','user_name','user_location']]

# %%
export
# Out:
#                   id_tweet  \
# 0      32424698159562752
# 1      32424745320325120
# 2      32425040838393856
# 3      37264842909954048
# 4      37289065355157504
# ...                  ...
# 50106  1156713143420239874
# 50107  1156713432802058243
# 50108  1156713689480871937
# 50109  1156713974693539841
# 50110  1156714344803164166
#
#                                                                                                                                                    text  \
# 0      RT @transitopolicia: atienden el choque simple entre una buseta y un taxi en la carrera séptima con calle 31, sentido sur – norte
# 1      RT @transitopolicia: calle 80 represada a la altura de la cra 116, lugar en el que una volqueta  permanece con fallas mecánicas, sentido ...
# 2      RT @transitopolicia: caída de un motociclista en la Av. Américas con Av. Boyacá, sentido occidente – oriente
# 3      Los camioneros que avanzan por la calle 80, transitan por la boyaca a la altura de la av la esperanza sentido norte-sur
# 4      Aut norte carril lento sentido norte sur choque simple entre 2 taxis,policia de transito en sitio, trafico lento por este carril
# ...                                                                                                                                 ...
# 50106  Incidente vial entre dos automóviles🚗 en la Carrera 10 C con Calle 30 Sur, sentido norte - sur.Unidad de 👮 @TransitoBta  asignada.
# 50107  Incidente vial entre automóvil 🚗y motociclista  🏍  en la Av. Boyaca con Av. Américas, sentido norte - sur.Unidad de 👮 @TransitoBta  asignada.
# 50108  Incidente vial entre bus 🚌 y automóvil 🚗 en la Calle 2  con Carrera 100, sentido occidente - oriente.Unidad de 👮 @TransitoBta  asignada.
# 50109  Incidente vial entre camión y automóvil 🚗 en la Calle 51 B Sur con Carrera 86 D, sentido oriente - occidente.Unidad de 👮 @TransitoBta  asignada.
# 50110  Incidente vial entre dos automóviles🚗 en la Carrera 18 con Calle 5, sentido norte - sur.Unidad de 👮 @TransitoBta  asignada.
#
#                 created_at       user_name      user_location
# 0      2011-02-01 08:07:05  CIVICOSBOG      Bogotá - Colombia
# 1      2011-02-01 08:07:16  CIVICOSBOG      Bogotá - Colombia
# 2      2011-02-01 08:08:26  CIVICOSBOG      Bogotá - Colombia
# 3      2011-02-14 16:40:05  CIVICOSBOG      Bogotá - Colombia
# 4      2011-02-14 18:16:20  CIVICOSBOG      Bogotá - Colombia
# ...                    ...         ...                    ...
# 50106  2019-07-31 18:47:58  BogotaTransito  Bogotá, Colombia
# 50107  2019-07-31 18:49:07  BogotaTransito  Bogotá, Colombia
# 50108  2019-07-31 18:50:08  BogotaTransito  Bogotá, Colombia
# 50109  2019-07-31 18:51:16  BogotaTransito  Bogotá, Colombia
# 50110  2019-07-31 18:52:45  BogotaTransito  Bogotá, Colombia
#
# [50111 rows x 5 columns]

# %%
export.to_csv(dir_+"export_only_BogotaTransito_"+filename,sep='\t')

# %%
pd.set_option('display.max_colwidth',-1)
#df[df['user_name'] != 'BogotaTransito'].keys()

# %%
df[['text','user_name']][4000:4080]
# Out:
#                                                                                                                                                               text  \
# 4000  💥  Incidente vial entre 2 particulares 🚘 en la Av. El Dorado con carrera 88, sentido oriente-occidente. Unidad de 👮 @TransitoBta asignada.
# 4001  💥  Incidente vial entre ambulancia 🚑 y ciclista 🚴‍♂️ en la Autosur con carrera 67, sentido Soacha a Bogotá. Unidad de 👮 @TransitoBta y 🚑 asignadas.
# 4002  💥  Incidente vial entre 2 particulares 🚘 en la  Carrera 68 con calle 13, sentido sur-norte.Unidad de 👮 @TransitoBta asignada.
# 4003  💥  Incidente vial entre particular 🚘 y un bus 🚌 en la Carrera 7 con calle 131 sentido norte-sur.Unidad de 👮 @TransitoBta asignada.
# 4004  Accidente en Autopista Sur &gt; Occidente #traficobogota. Tráfico 37m más lento de lo habitual. https://t.co/moHLMdsqt5 https://t.co/cbOSQTpWuo
# ...                                                                                                                                               ...
# 4075  💥  Incidente vial entre particulares 🚘 en la Autosur con Av. Boyaca, sentido norte - sur. Unidad de 👮 @TransitoBta asignada.
# 4076  💥  Incidente vial entre particulares 🚘 en la Av. Ciudad de Cali con calle 10, sentido norte - sur. Unidad de 👮 @TransitoBta asignada.
# 4077  💥  Incidente vial entre particulares 🚘 en la carrera  7 con calle 170, sentido sur - norte. Unidad de 👮 @TransitoBta asignada.
# 4078  💥  Incidente vial entre particular 🚘 y camión 🚛 en la Autosur con carrera 65, sentido oriente - occidente. Unidad de 👮 @TransitoBta asignada.
# 4079  💥  Incidente vial entre particular 🚘 y motociclista 🏍 en la Av. 1 de Mayo con carrera  68 D, sentido occidente - oriente. Unidad de 👮 @TransitoBta asignada.
#
#            user_name
# 4000  BogotaTransito
# 4001  BogotaTransito
# 4002  BogotaTransito
# 4003  BogotaTransito
# 4004  WazeTrafficBOG
# ...              ...
# 4075  BogotaTransito
# 4076  BogotaTransito
# 4077  BogotaTransito
# 4078  BogotaTransito
# 4079  BogotaTransito
#
# [80 rows x 2 columns]

# %%
df[df['user_name'] == 'RedapBogota'][['text','user_name']][0:40]
# Out:
#                                                                                                                                                                                                                                                      text  \
# 757  Por la calle 17 Sur con carrera 19 al occidente chocan dos vehículos particulares
# 759  RT @WazeTrafficBOG: Accidente en Av. Caracas &gt; Norte #traficobogota. Tráfico 26m más lento de lo habitual. https://t.co/LcedudG2zf https://…
# 798  Calle 10 sur Carrera 15 fuerte estrellada Buseta y camión ya hay recursos en el punto
# 799  Mujer fallecida en puente peatonal calle 45 con 30 lado derecho de la rampa. Ya Cruz roja y dos policías bachilleres.
# 800  AK 68 antes de la av la esperanza sentido sur norte choque simple de furgón vs particular, se requiere tránsito.
# 822  [9:13, 8/12/2017] +57 350 5533501: Congestión en la Calle 13 con Av. Boyacá, por colisión entre dos vehiculos
# 823  14:02 1 DE MAYO X 50 SUR OR-OC: Se presenta choque entre  carrotanque y particular
# 824  Informan boyacá por kr 24 S&gt;N lesionado en accidente de tránsito ya de ambulancia se necesita tránsito
# 835  Por la carrera 80 con calle 59 Sur en Bosa Centro un taxi y una motocicleta chocan, dos personas lesionadas
# 836  Por la carrera 26 D con calle 35 Sur en sentido sur – norte un choque entre una motocicleta y un vehículo particular deja lesiones en una persona
# 838  avenida Boyacá con calle 137 al sur un vehículo particular y una motocicleta involucrados, una persona lesionada
# 839  Choque simple  Boyacá  al norte con 134 norte al sur, solicitan tránsito. Bastante trancon a la hora.
# 841  informan de posible  muerto en accidente de transito (Tractocamion y peatón) por la av ciudad de cali a la altura de la biblioteca tintal sentido Norte sur
# 842  avenida Ciudad de Cali x cl 6 en el tintal norte - sur choque con  persona fallecida
# 852  @esrobado vehículo Toyota Prado XL 2018 color Gris DZY789 en la calle 74D 72 57 Chapinero - Bogotá #esrobado
# 853  Choque simple entre un particular y una motocicleta sobre la Av boyacá con calle 13 debajo del puente carril central de Sur a Norte gran trancón tomar carril lento desde calle 12 al norte
# 854  Fuerte congestión avenida Boyacá con avenida Américas de sur a norte
# 855  6:10BOYACA X 13 s-n: Se presenta choque entre particular y moto con lesionado, se asigna unidad de tránsito (cuadrante 80-2) y ambulancia 5256
# 856  En la Autopista Sur con Carrera 65, sentido Occidente-Oriente, se presenta un choque simple entre dos vehículos particulares. El hecho no deja personadas lesionadas.
# 857  Calle 58 C Sur con Carrera 86 A, sentido Oriente-Occidente se presenta choque simple entre un camión y un taxi, sin que deje heridos.
# 858  En la Avenida Boyacá con Calle 17, sentido Sur-Norte hay un choque entre un particular y una motocicleta. No hay lesionados.
# 859  En la Carrera 97 con Calle 13, sentido Norte-Sur, se presenta un choque entre dos vehículos particulares, sin heridos.
# 860  En la Carrera 10 con Calle 4, sentido Sur-Norte,  se presenta un choque simple entre un bus y un vehículo particular con afectación del tráfico del sector y daños materiales.
# 861  choque entre dos vehículos particulares en la Calle 26 con Cra 50 sentido Occidente Oriente debajo del puente en el carril central. La congestión vehicular viene desde la Av boyacá y no hay tránsito en el punto. Por favor enviar unidad urgente
# 872  Accidente de tránsito con persona fallecida ya hay unidades Pero hay gran trancón calle 63 carrera 111C femenina de 50 a 55 años
# 881  @TransitoPolicia 5:48 Buenos dias, nos pueden colaborar con policia de transito en la Calle 72 por Carrera 80A, sentido Occidente-Oriente, se presenta un accidente de transito entre bus del TPC y particular lo cual no dejo paso
# 882  Avenida Boyacá con 43a sur se presenta este accidente solo latas  entre carrotanque taxi y volquete bloquea totalmente la Boyacá de norte a sur carril lento se solicita tránsito
# 883  Avenida Boyacá con 43a sur se presenta este accidente solo latas  entre carrotanque taxi y volquete bloquea... https://t.co/l7Ggrmi2I5
# 886  Av cali, con 26, con 13 y tintal. Fuerte trancon
# 887  Av Américas alto flujo vehicular entre cr 68 y av Boyacá
# 888  Cra 106 calle 65 choque simple de particulares, no deja paso en la via se requiere transito.
# 898  Se reportan dos incidentes viales en la Av. Circunvalar con Cll20, sentido sur - norte, el primero de ellos un choque múltiple entre tres particulares, y el segundo un choque entre un bus y camión. Transito trabaja en el retiro de los vehículos
# 899  Se reportan dos incidentes viales en la Av. Circunvalar con Cll20, sentido sur - norte, el primero de ellos un... https://t.co/btzFHPpCp0
# 905  Por la calle 1 Sur con carrera 25 choca una motocicleta con un bus del SITP, dos personas lesionadas
# 906  Por la calle 34 A Sur con carrera 88 D al occidente chocan una motocicleta y un vehículo tipo furgoneta, una persona lesionada
# 907  Por la carrera 111 A con calle 25 J sur – norte chocan dos vehículos particulares
# 908  Por la carrera 13 con calle 19 Sur al norte chocan dos vehículos particulares
# 909  Informan fuerte trancón en la avenida Cali hacia el norte en el sector de patio bonito tintal
# 910  @SectorMovilidad @SectorSalud Lesionado en accidente de tránsito motera calle 43 a sur con 30 Oriente occidente se solicita ambulancia y tránsito
# 911  EVENTOS QUE GENERAN TRAFICO LENTO Por la avenida Suba con avenida Boyacá en sentido sur – norte un vehículo particular atropella aun peatón, una persona lesionada
#
#        user_name
# 757  RedapBogota
# 759  RedapBogota
# 798  RedapBogota
# 799  RedapBogota
# 800  RedapBogota
# 822  RedapBogota
# 823  RedapBogota
# 824  RedapBogota
# 835  RedapBogota
# 836  RedapBogota
# 838  RedapBogota
# 839  RedapBogota
# 841  RedapBogota
# 842  RedapBogota
# 852  RedapBogota
# 853  RedapBogota
# 854  RedapBogota
# 855  RedapBogota
# 856  RedapBogota
# 857  RedapBogota
# 858  RedapBogota
# 859  RedapBogota
# 860  RedapBogota
# 861  RedapBogota
# 872  RedapBogota
# 881  RedapBogota
# 882  RedapBogota
# 883  RedapBogota
# 886  RedapBogota
# 887  RedapBogota
# 888  RedapBogota
# 898  RedapBogota
# 899  RedapBogota
# 905  RedapBogota
# 906  RedapBogota
# 907  RedapBogota
# 908  RedapBogota
# 909  RedapBogota
# 910  RedapBogota
# 911  RedapBogota
