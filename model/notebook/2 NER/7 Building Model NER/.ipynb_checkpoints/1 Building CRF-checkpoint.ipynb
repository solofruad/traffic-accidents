# %% [markdown]
# # Building Model CRF
# ### By **Néstor Suat** in 2020
#
# **Descripción:** Generando un modelo ML para la tarea de NER en tweets de accidentes para las etiquetas `loc` y `time` usando el estandar BIO.
#
# **Input:**
# * TSV con dataset etiquetado con BIO
#
# **Output:**
# * Model
#
# **Tomado de**: https://www.depends-on-the-definition.com/named-entity-recognition-conditional-random-fields-python/
# ***

# %% [markdown]
# ### Importando librerías

# %%
import pandas as pd

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            #s = self.grouped["Sentence: {}".format(self.n_sent)]
            s = self.grouped[self.n_sent]
            self.n_sent += 1
            return s
        except:
            return None

# %% [markdown]
# ### Craft features
#
# Now we craft a set of features and prepare the dataset.

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %% [markdown]
# ### Importando dataset anotado

# %%
file = 'ner-crf-training-data.tsv'
dir_ = "../../../data/v1/NER/"
data = pd.read_csv(dir_+file, delimiter = "\t", quoting = 3, names=['Sentence #','Word','POS','Tag'])
#dataset[:50]

# %%
words = list(set(data['Word'].values))
n_words = len(words)
n_words
# Out:
# 455

# %%
getter = SentenceGetter(data)

# %%
sent = getter.get_next()
print(sent)
# Out:
# [('2', 'NUM', 'O'), ('ciclistas', 'NOUN', 'O'), ('muertos', 'ADJ', 'O'), ('hoy', 'ADV', 'B-time'), ('de', 'ADP', 'O'), ('5:30', 'NUM', 'B-time'), ('am', 'NOUN', 'I-time'), ('a', 'ADP', 'I-time'), ('9:45', 'NUM', 'I-time'), ('am', 'NOUN', 'I-time'), ('en', 'ADP', 'O'), ('el', 'DET', 'O'), ('corto', 'ADJ', 'O'), ('tramo', 'NOUN', 'O'), ('de', 'ADP', 'O'), ('puente', 'NOUN', 'B-loc'), ('guaduas', 'ADJ', 'I-loc'), ('al', 'ADP', 'I-loc'), ('puente', 'NOUN', 'I-loc'), ('de', 'ADP', 'I-loc'), ('la', 'DET', 'I-loc'), ('rotonda', 'NOUN', 'I-loc'), ('de', 'ADP', 'I-loc'), ('Siberia', 'PROPN', 'I-loc'), ('.', 'PUNCT', 'O'), ('.', 'PUNCT', 'O'), ('este', 'DET', 'O'), ('año', 'NOUN', 'O'), ('en', 'ADP', 'O'), ('ese', 'DET', 'O'), ('mismo', 'DET', 'O'), ('tramo', 'NOUN', 'O'), ('van', 'VERB', 'O'), ('por', 'ADP', 'O'), ('poquito', 'PRON', 'O'), ('10', 'NUM', 'O'), ('ciclistas', 'NOUN', 'O'), ('muertos', 'ADJ', 'O'), ('por', 'ADP', 'O'), ('accidente', 'NOUN', 'O'), (',', 'PUNCT', 'O'), ('delicado', 'ADJ', 'O'), ('ese', 'DET', 'O'), ('asunto', 'NOUN', 'O'), ('.', 'PUNCT', 'O')]

# %%
sentences = getter.sentences
sentences
# Out:
# [[('sectormovilidad', 'NOUN', 'O'),
#   ('giro', 'NOUN', 'O'),
#   ('paa', 'NOUN', 'O'),
#   ('tomar', 'VERB', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('80', 'NUM', 'I-loc'),
#   ('al', 'ADP', 'O'),
#   ('occidente', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('av', 'NOUN', 'B-loc'),
#   ('Boyaca', 'PROPN', 'I-loc'),
#   ('bloqueado', 'ADJ', 'O'),
#   ('por', 'ADP', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('simple', 'ADJ', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('paso', 'NOUN', 'O'),
#   ('bloqueado', 'ADJ', 'O')],
#  [('sectormovilidad', 'NOUN', 'O'),
#   ('hubo', 'AUX', 'O'),
#   ('un', 'DET', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('sitp', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('una', 'DET', 'O'),
#   ('camioneta', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('oreja', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('68', 'NOUN', 'B-loc'),
#   ('que', 'PRON', 'I-loc'),
#   ('sale', 'VERB', 'I-loc'),
#   ('a', 'ADP', 'I-loc'),
#   ('las', 'DET', 'I-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('hacia', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('occidente', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('tienen', 'VERB', 'O'),
#   ('todo', 'DET', 'O'),
#   ('el', 'DET', 'O'),
#   ('tráfico', 'NOUN', 'O'),
#   ('retenido', 'ADJ', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('hay', 'AUX', 'O'),
#   ('una', 'DET', 'O'),
#   ('ambulancia', 'NOUN', 'O'),
#   ('!!', 'ADJ', 'O')],
#  [('2', 'NUM', 'O'),
#   ('ciclistas', 'NOUN', 'O'),
#   ('muertos', 'ADJ', 'O'),
#   ('hoy', 'ADV', 'B-time'),
#   ('de', 'ADP', 'O'),
#   ('5:30', 'NUM', 'B-time'),
#   ('am', 'NOUN', 'I-time'),
#   ('a', 'ADP', 'I-time'),
#   ('9:45', 'NUM', 'I-time'),
#   ('am', 'NOUN', 'I-time'),
#   ('en', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('corto', 'ADJ', 'O'),
#   ('tramo', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('puente', 'NOUN', 'B-loc'),
#   ('guaduas', 'ADJ', 'I-loc'),
#   ('al', 'ADP', 'I-loc'),
#   ('puente', 'NOUN', 'I-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('la', 'DET', 'I-loc'),
#   ('rotonda', 'NOUN', 'I-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('Siberia', 'PROPN', 'I-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('este', 'DET', 'O'),
#   ('año', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('ese', 'DET', 'O'),
#   ('mismo', 'DET', 'O'),
#   ('tramo', 'NOUN', 'O'),
#   ('van', 'VERB', 'O'),
#   ('por', 'ADP', 'O'),
#   ('poquito', 'PRON', 'O'),
#   ('10', 'NUM', 'O'),
#   ('ciclistas', 'NOUN', 'O'),
#   ('muertos', 'ADJ', 'O'),
#   ('por', 'ADP', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('delicado', 'ADJ', 'O'),
#   ('ese', 'DET', 'O'),
#   ('asunto', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('Accidente', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('lesionado', 'ADJ', 'O'),
#   ('de', 'ADP', 'O'),
#   ('una', 'DET', 'O'),
#   ('ruta', 'NOUN', 'O'),
#   ('escolar', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('cl', 'NOUN', 'B-loc'),
#   ('146', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('81', 'NUM', 'I-loc'),
#   ('ya', 'ADV', 'O'),
#   ('en', 'ADP', 'O'),
#   ('desplazamiento', 'NOUN', 'O'),
#   ('unidad', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('bomberos', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('estación', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('suba', 'VERB', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('Bicentenario', 'PROPN', 'O')],
#  [('transito', 'ADJ', 'O'),
#   ('policia', 'NOUN', 'O'),
#   ('sectormovilidad', 'ADJ', 'O'),
#   ('La', 'DET', 'O'),
#   ('autopista', 'PROPN', 'B-loc'),
#   ('Norte', 'PROPN', 'I-loc'),
#   ('está', 'AUX', 'O'),
#   ('completamente', 'ADV', 'O'),
#   ('quieta', 'ADJ', 'O'),
#   ('desde', 'ADP', 'O'),
#   ('la', 'DET', 'B-loc'),
#   ('Caro', 'PROPN', 'I-loc'),
#   ('hacia', 'ADP', 'O'),
#   ('Bogotá', 'PROPN', 'B-loc'),
#   ('por', 'ADP', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('cerca', 'ADV', 'O'),
#   ('del', 'ADP', 'O'),
#   ('club', 'NOUN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('colsubsidio', 'NOUN', 'I-loc')],
#  [('Autonorte', 'VERB', 'B-loc'),
#   ('por', 'ADP', 'I-loc'),
#   ('183', 'NUM', 'I-loc'),
#   ('sentido', 'NOUN', 'O'),
#   ('Sur-Norte', 'PROPN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('vehículo', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('servicio', 'NOUN', 'O'),
#   ('público', 'ADJ', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('particular', 'ADJ', 'O'),
#   ('que', 'PRON', 'O')],
#  [('transito', 'NOUN', 'O'),
#   ('A', 'ADP', 'O'),
#   ('esta', 'DET', 'O'),
#   ('hora', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('se', 'PRON', 'O'),
#   ('registra', 'VERB', 'O'),
#   ('el', 'DET', 'O'),
#   ('volcamiento', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('una', 'DET', 'O'),
#   ('ambulancia', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('carrera', 'NOUN', 'B-loc'),
#   ('30', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('64', 'NUM', 'I-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('Autoridades', 'PROPN', 'O'),
#   ('atienden', 'VERB', 'O'),
#   ('la', 'DET', 'O'),
#   ('situación', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('accidente', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('fatalidad', 'NOUN', 'O'),
#   ('Avenida', 'PROPN', 'B-loc'),
#   ('Cali', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'PROPN', 'I-loc'),
#   ('23D', 'PROPN', 'I-loc'),
#   ('Sur', 'PROPN', 'O'),
#   ('Norte', 'PROPN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('camión', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('gaseosas', 'NOUN', 'O'),
#   ('contra', 'ADP', 'O'),
#   ('motociclista', 'NOUN', 'O'),
#   ('que', 'PRON', 'O'),
#   ('resulta', 'VERB', 'O'),
#   ('fallecido', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('sitio', 'NOUN', 'O')],
#  [('transmilenio', 'NOUN', 'O'),
#   ('transmilenio', 'ADJ', 'O'),
#   ('porquería', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('todos', 'DET', 'O'),
#   ('los', 'DET', 'O'),
#   ('días', 'NOUN', 'O'),
#   ('lo', 'DET', 'O'),
#   ('mismo', 'ADJ', 'O'),
#   ('viernes', 'NOUN', 'B-time'),
#   ('por', 'ADP', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('latas', 'NOUN', 'O'),
#   ('Caracas', 'PROPN', 'B-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('24', 'NUM', 'I-loc'),
#   ('y', 'CCONJ', 'O'),
#   ('hoy', 'ADV', 'B-time'),
#   ('un', 'DET', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('simple', 'ADJ', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('no', 'ADV', 'O'),
#   ('hay', 'AUX', 'O'),
#   ('contingencia', 'NOUN', 'O'),
#   ('imbéciles', 'ADJ', 'O')],
#  [('camarada', 'NOUN', 'O'),
#   ('motero', 'NOUN', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('auto', 'NOUN', 'B-loc'),
#   ('norte', 'ADJ', 'I-loc'),
#   ('sentido', 'VERB', 'O'),
#   ('sur', 'NOUN', 'O'),
#   ('norte', 'ADJ', 'O'),
#   ('a', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('altura', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('66', 'NUM', 'I-loc'),
#   ('grabe', 'NOUN', 'O')],
#  [('Acabo', 'PROPN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('ver', 'VERB', 'O'),
#   ('como', 'SCONJ', 'O'),
#   ('un', 'DET', 'O'),
#   ('transmilenio', 'NOUN', 'O'),
#   ('atropelló', 'VERB', 'O'),
#   ('a', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('joven', 'NOUN', 'O'),
#   ('que', 'PRON', 'O'),
#   ('se', 'PRON', 'O'),
#   ('iba', 'AUX', 'O'),
#   ('a', 'ADP', 'O'),
#   ('colar', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('estacion', 'NOUN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('la', 'DET', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('106', 'NUM', 'I-loc'),
#   ('sentido', 'NOUN', 'O'),
#   ('sur', 'ADJ', 'O'),
#   ('norte', 'ADJ', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('No', 'ADV', 'O'),
#   ('entiendo', 'VERB', 'O'),
#   ('por', 'ADP', 'O'),
#   ('que', 'SCONJ', 'O'),
#   ('la', 'DET', 'O'),
#   ('gente', 'NOUN', 'O'),
#   ('arriesga', 'VERB', 'O'),
#   ('su', 'DET', 'O'),
#   ('vida', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('esa', 'DET', 'O'),
#   ('forma', 'NOUN', 'O'),
#   ('!!', 'ADJ', 'O'),
#   ('Ya', 'ADV', 'O'),
#   ('llame', 'VERB', 'O'),
#   ('al', 'ADP', 'O'),
#   ('123', 'NUM', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('una', 'DET', 'O'),
#   ('ambulancia', 'NOUN', 'O'),
#   ('va', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('camino', 'NOUN', 'O'),
#   ('transmilenio', 'ADJ', 'O')],
#  [('citytv', 'NOUN', 'O'),
#   ('noticiascaracol', 'ADJ', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('cra', 'NOUN', 'B-loc'),
#   ('7ma', 'ADJ', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('183', 'NUM', 'I-loc')],
#  [('A', 'ADP', 'O'),
#   ('esta', 'DET', 'O'),
#   ('hora', 'NOUN', 'O'),
#   ('nuestras', 'DET', 'O'),
#   ('unidades', 'NOUN', 'O'),
#   ('atienden', 'VERB', 'O'),
#   ('dos', 'NUM', 'O'),
#   ('accidentes', 'NOUN', 'O'),
#   ('ocurridos', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Av.', 'PROPN', 'B-loc'),
#   ('.', 'PUNCT', 'I-loc'),
#   ('Boyaca', 'PROPN', 'I-loc'),
#   ('por', 'ADP', 'I-loc'),
#   ('170', 'NUM', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('donde', 'PRON', 'O'),
#   ('uno', 'PRON', 'O'),
#   ('de', 'ADP', 'O'),
#   ('los', 'DET', 'O'),
#   ('accidentes', 'NOUN', 'O'),
#   ('es', 'AUX', 'O'),
#   ('un', 'DET', 'O'),
#   ('atropellamiento', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('una', 'DET', 'O'),
#   ('persona', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('bicicleta', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('el', 'DET', 'O'),
#   ('otro', 'DET', 'O'),
#   ('incidente', 'NOUN', 'O')],
#  [('En', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('av', 'NOUN', 'B-loc'),
#   ('boyacá', 'VERB', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('62', 'NUM', 'I-loc'),
#   ('sur', 'NOUN', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('norte', 'ADJ', 'O'),
#   ('sur', 'ADJ', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('simple', 'ADJ', 'O'),
#   ('de', 'ADP', 'O'),
#   ('camión', 'NOUN', 'O'),
#   ('vs', 'NOUN', 'O'),
#   ('zonal', 'ADJ', 'O'),
#   ('provisional', 'ADJ', 'O'),
#   ('paso', 'NOUN', 'O'),
#   ('reducido', 'ADJ', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('se', 'PRON', 'O'),
#   ('solicita', 'VERB', 'O'),
#   ('tránsito', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('Nuestras', 'DET', 'O'),
#   ('unidades', 'NOUN', 'O'),
#   ('atendieron', 'VERB', 'O'),
#   ('a', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('ciclista', 'NOUN', 'O'),
#   ('que', 'PRON', 'O'),
#   ('resultó', 'VERB', 'O'),
#   ('herido', 'ADJ', 'O'),
#   ('tras', 'ADP', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('furgón', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('131', 'NUM', 'I-loc'),
#   ('por', 'ADP', 'I-loc'),
#   ('59', 'NUM', 'I-loc'),
#   ('.', 'PUNCT', 'O')],
#  [('sectormovilidad', 'NOUN', 'O'),
#   ('policiabogota', 'ADJ', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('puente', 'NOUN', 'B-loc'),
#   ('Boyacá', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('80', 'NUM', 'I-loc'),
#   ('de', 'ADP', 'O'),
#   ('oriente', 'NOUN', 'O'),
#   ('a', 'ADP', 'O'),
#   ('occidente', 'NOUN', 'O')],
#  [('Motociclista', 'PROPN', 'O'),
#   ('muere', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('impactante', 'ADJ', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('contra', 'ADP', 'O'),
#   ('camión', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('Corabastos', 'PROPN', 'B-loc'),
#   (',', 'PUNCT', 'O'),
#   ('Bogotá', 'PROPN', 'O'),
#   ('vía', 'ADP', 'O'),
#   ('cablenoticias', 'NOUN', 'O')],
#  [('citytv', 'NOUN', 'O'),
#   ('caracol', 'NOUN', 'O'),
#   ('tv', 'NOUN', 'O'),
#   ('caracolradio', 'ADJ', 'O'),
#   ('la', 'DET', 'O'),
#   ('fm', 'NOUN', 'O'),
#   ('erika', 'ADJ', 'O'),
#   ('fontalvo', 'ADJ', 'O'),
#   ('gusgomez1701', 'NUM', 'O'),
#   ('muerto', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('Caracas', 'PROPN', 'I-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('(', 'PUNCT', 'O'),
#   ('Actualización', 'NOUN', 'O'),
#   (')', 'PUNCT', 'O'),
#   ('Catorce', 'NUM', 'O'),
#   ('heridos', 'NOUN', 'O'),
#   ('por', 'ADP', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('buses', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('TM', 'PROPN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('estación', 'NOUN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('la', 'DET', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('100', 'NUM', 'I-loc')],
#  [('¿', 'PUNCT', 'O'),
#   ('Calle', 'PROPN', 'O'),
#   ('o', 'CCONJ', 'O'),
#   ('piscina', 'NOUN', 'O'),
#   ('?', 'PUNCT', 'O'),
#   ('dos', 'NUM', 'O'),
#   ('vehículos', 'NOUN', 'O'),
#   ('han', 'AUX', 'O'),
#   ('quedado', 'VERB', 'O'),
#   ('atrapados', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('las', 'DET', 'O'),
#   ('últimas', 'ADJ', 'O'),
#   ('horas', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('este', 'DET', 'O'),
#   ('enorme', 'ADJ', 'O'),
#   ('hueco', 'NOUN', 'O'),
#   ('ubicado', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Calle', 'PROPN', 'B-loc'),
#   ('9', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('carrera', 'NOUN', 'I-loc'),
#   ('36', 'NUM', 'I-loc'),
#   ('-', 'PUNCT', 'O'),
#   ('Puente', 'PROPN', 'O'),
#   ('Aranda', 'PROPN', 'O'),
#   ('arriba', 'ADV', 'O'),
#   ('bogota', 'ADJ', 'O'),
#   ('citytv', 'NOUN', 'O')],
#  [('Accidente', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('106', 'NUM', 'B-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('9', 'NUM', 'I-loc')],
#  [('bogotatransito', 'NOUN', 'O'),
#   ('sectormovilidad', 'NOUN', 'O'),
#   ('Se', 'PRON', 'O'),
#   ('solicita', 'VERB', 'O'),
#   ('transito', 'ADJ', 'O'),
#   ('policia', 'NOUN', 'O'),
#   ('para', 'ADP', 'O'),
#   ('controlar', 'VERB', 'O'),
#   ('congestión', 'NOUN', 'O'),
#   ('producida', 'ADJ', 'O'),
#   ('por', 'ADP', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('tractocamión', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('particular', 'NOUN', 'O'),
#   ('Avenida', 'PROPN', 'B-loc'),
#   ('calle', 'PROPN', 'I-loc'),
#   ('80', 'NUM', 'I-loc'),
#   ('hacia', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('occidente', 'NOUN', 'O'),
#   ('bajo', 'ADP', 'B-loc'),
#   ('el', 'DET', 'I-loc'),
#   ('puente', 'NOUN', 'I-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('la', 'DET', 'I-loc'),
#   ('avenida', 'NOUN', 'I-loc'),
#   ('Ciudad', 'PROPN', 'I-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('Cali', 'PROPN', 'I-loc')],
#  [('Choque', 'NOUN', 'O'),
#   ('frente', 'NOUN', 'O'),
#   ('a', 'ADP', 'O'),
#   ('Cafam', 'PROPN', 'B-loc'),
#   ('floresta', 'ADJ', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('occidente', 'ADJ', 'O'),
#   ('oriente', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('Sitp', 'PROPN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('particular', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('No', 'ADV', 'O'),
#   ('informan', 'VERB', 'O'),
#   ('sentido', 'NOUN', 'O')],
#  [('sectormovilidad', 'NOUN', 'O'),
#   ('transmilenio', 'ADJ', 'O'),
#   ('bus', 'NOUN', 'O'),
#   ('dual', 'ADJ', 'O'),
#   ('se', 'PRON', 'O'),
#   ('estrella', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('taxi', 'NOUN', 'O'),
#   ('subiendo', 'VERB', 'O'),
#   ('por', 'ADP', 'O'),
#   ('la', 'DET', 'B-loc'),
#   ('72', 'NUM', 'I-loc')],
#  [('Accidente', 'NOUN', 'O'),
#   ('roce', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('SITP', 'PROPN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('carro', 'NOUN', 'O'),
#   ('particular', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('53', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('24', 'NUM', 'I-loc'),
#   ('(', 'PUNCT', 'O'),
#   ('Panamericana', 'PROPN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('Galerías', 'PROPN', 'I-loc'),
#   (')', 'PUNCT', 'O')],
#  [('Cr', 'NOUN', 'B-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('A', 'ADP', 'I-loc'),
#   ('por', 'ADP', 'I-loc'),
#   ('8', 'NUM', 'I-loc'),
#   ('sur', 'NOUN', 'I-loc'),
#   ('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('vehículo', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('servicio', 'NOUN', 'O'),
#   ('público', 'ADJ', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('motocicleta', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('Una', 'DET', 'O'),
#   ('persona', 'NOUN', 'O'),
#   ('lesionada', 'ADJ', 'O')],
#  [('Bus', 'PROPN', 'O'),
#   ('del', 'ADP', 'O'),
#   ('SITP', 'PROPN', 'O'),
#   ('se', 'PRON', 'O'),
#   ('volcó', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Av.', 'PROPN', 'B-loc'),
#   ('.', 'PUNCT', 'I-loc'),
#   ('Boyacá', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('Las', 'DET', 'O'),
#   ('autoridades', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('tránsito', 'NOUN', 'O'),
#   ('cerraron', 'VERB', 'O'),
#   ('por', 'ADP', 'O'),
#   ('unos', 'DET', 'O'),
#   ('minutos', 'NOUN', 'O'),
#   ('la', 'DET', 'O'),
#   ('Avenida', 'PROPN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('norte', 'ADJ', 'O'),
#   ('sur', 'ADJ', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('para', 'ADP', 'O'),
#   ('atender', 'VERB', 'O'),
#   ('el', 'DET', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('recoger', 'VERB', 'O'),
#   ('el', 'DET', 'O'),
#   ('bus', 'NOUN', 'O'),
#   ('que', 'PRON', 'O'),
#   ('sufrió', 'VERB', 'O'),
#   ('grandes', 'ADJ', 'O'),
#   ('afectaciones', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('parte', 'NOUN', 'O'),
#   ('frontal', 'ADJ', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('citytv', 'NOUN', 'O'),
#   ('arriba', 'ADV', 'O'),
#   ('bogota', 'ADJ', 'O'),
#   ('j', 'NOUN', 'O'),
#   ('camilo', 'ADJ', 'O'),
#   ('ramirez', 'ADJ', 'O'),
#   ('g', 'SYM', 'O')],
#  [('sectormovilidad', 'NOUN', 'O'),
#   ('Trancón', 'PROPN', 'O'),
#   ('monumental', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('autonorte', 'NOUN', 'B-loc'),
#   ('a', 'ADP', 'I-loc'),
#   ('la', 'DET', 'I-loc'),
#   ('altura', 'NOUN', 'I-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('la', 'DET', 'I-loc'),
#   ('estación', 'NOUN', 'I-loc'),
#   ('Prado', 'PROPN', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('por', 'ADP', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('motociclista', 'NOUN', 'O'),
#   ('fallecido', 'ADJ', 'O')],
#  [('En', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('operativo', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('anoche', 'ADV', 'B-time'),
#   ('viernes', 'NOUN', 'B-time'),
#   ('10', 'NUM', 'I-time'),
#   ('de', 'ADP', 'I-time'),
#   ('mayo', 'NOUN', 'I-time'),
#   ('nuestras', 'DET', 'O'),
#   ('unidades', 'NOUN', 'O'),
#   ('atendieron', 'VERB', 'O'),
#   ('un', 'DET', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('ocurrido', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('cra', 'NOUN', 'B-loc'),
#   ('70', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('72', 'NUM', 'I-loc'),
#   ('donde', 'PRON', 'O'),
#   ('el', 'DET', 'O'),
#   ('conductor', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('una', 'DET', 'O'),
#   ('motocicleta', 'NOUN', 'O'),
#   ('resultó', 'VERB', 'O'),
#   ('lesionado', 'ADJ', 'O'),
#   ('por', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('choque', 'NOUN', 'O')],
#  [('lo', 'DET', 'O'),
#   ('ultimo', 'ADJ', 'O'),
#   ('Dos', 'NUM', 'O'),
#   ('personas', 'NOUN', 'O'),
#   ('heridas', 'ADJ', 'O'),
#   ('luego', 'ADV', 'O'),
#   ('de', 'ADP', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('camión', 'NOUN', 'O'),
#   ('recolector', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('basuras', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('un', 'DET', 'O'),
#   ('taxi', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Carrera', 'PROPN', 'B-loc'),
#   ('10', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('Calle', 'PROPN', 'I-loc'),
#   ('27', 'NUM', 'I-loc'),
#   ('sur', 'NOUN', 'I-loc'),
#   ('me', 'PRON', 'O'),
#   ('paso', 'VERB', 'O'),
#   ('a', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('fm', 'NOUN', 'O')],
#  [('Grave', 'ADJ', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('zona', 'NOUN', 'O'),
#   ('del', 'ADP', 'O'),
#   ('parque', 'NOUN', 'B-loc'),
#   ('Lourdes', 'PROPN', 'I-loc'),
#   ('en', 'ADP', 'O'),
#   ('Chapinero', 'PROPN', 'B-loc')],
#  [('Choque', 'NOUN', 'O'),
#   ('multiple', 'ADJ', 'O'),
#   ('Av', 'PROPN', 'B-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('a', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('altura', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('Carrera', 'PROPN', 'B-loc'),
#   ('13', 'NUM', 'I-loc')],
#  [('bogotatransito', 'NOUN', 'O'),
#   ('sectormovilidad', 'NOUN', 'O'),
#   ('transitobta', 'ADJ', 'O'),
#   ('En', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('estacion', 'NOUN', 'B-loc'),
#   ('Olaya', 'PROPN', 'I-loc'),
#   ('que', 'PRON', 'O'),
#   ('paralizó', 'VERB', 'O'),
#   ('4', 'NUM', 'O'),
#   ('carriles', 'NOUN', 'O'),
#   ('por', 'ADP', 'O'),
#   ('una', 'DET', 'O'),
#   ('hora', 'NOUN', 'O'),
#   ('por', 'ADP', 'O'),
#   ('que', 'PRON', 'O'),
#   ('no', 'ADV', 'O'),
#   ('asignaron', 'VERB', 'O'),
#   ('unidades', 'NOUN', 'O'),
#   ('ni', 'CCONJ', 'O'),
#   ('informaron', 'VERB', 'O'),
#   ('por', 'ADP', 'O'),
#   ('este', 'DET', 'O'),
#   ('medio', 'NOUN', 'O'),
#   ('??', 'ADJ', 'O')],
#  [('atencion', 'VERB', 'O'),
#   ('Accidente', 'PROPN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Autopista', 'PROPN', 'B-loc'),
#   ('Norte', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('Calle', 'PROPN', 'I-loc'),
#   ('116', 'NUM', 'I-loc'),
#   ('en', 'ADP', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('sur', 'ADJ', 'O'),
#   ('norte', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('bogota', 'NOUN', 'O'),
#   ('me', 'PRON', 'O'),
#   ('paso', 'VERB', 'O'),
#   ('a', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('fm', 'NOUN', 'O')],
#  [('red', 'NOUN', 'O'),
#   ('a', 'ADP', 'O'),
#   ('p', 'NOUN', 'O'),
#   ('bogota', 'ADJ', 'O'),
#   ('bogota', 'ADJ', 'O'),
#   ('se', 'PRON', 'O'),
#   ('mueve', 'VERB', 'O'),
#   ('sectormovilidad', 'NOUN', 'O'),
#   ('policiabogota', 'ADJ', 'O'),
#   ('Accidente', 'PROPN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('2', 'NUM', 'O'),
#   ('vehiculos', 'NOUN', 'O'),
#   ('sobre', 'ADP', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('carrera', 'NOUN', 'I-loc'),
#   ('65', 'NUM', 'I-loc'),
#   ('carril', 'NOUN', 'O'),
#   ('central', 'ADJ', 'O'),
#   ('bloquea', 'VERB', 'O'),
#   ('el', 'DET', 'O'),
#   ('trafico', 'NOUN', 'O'),
#   ('hacia', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('oriente', 'NOUN', 'O')],
#  [('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('dos', 'NUM', 'O'),
#   ('particulares', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('26', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('carrera', 'NOUN', 'I-loc'),
#   ('102', 'NUM', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('occ-or', 'NOUN', 'O')],
#  [('transitobta', 'VERB', 'O'),
#   ('bogota', 'NOUN', 'O'),
#   ('se', 'PRON', 'O'),
#   ('mueve', 'VERB', 'O'),
#   ('Choque', 'PROPN', 'O'),
#   ('simple', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('Avenida', 'PROPN', 'B-loc'),
#   ('68', 'NUM', 'I-loc'),
#   ('al', 'ADP', 'O'),
#   ('frente', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('cancha', 'NOUN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('Beisbol', 'PROPN', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('costado', 'VERB', 'O'),
#   ('norte', 'NOUN', 'O'),
#   ('sur', 'ADJ', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('Por', 'ADP', 'O'),
#   ('favor', 'NOUN', 'O'),
#   ('enviar', 'VERB', 'O'),
#   ('unidad', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('citynoticias', 'NOUN', 'O'),
#   ('Por', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('caída', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('árbol', 'NOUN', 'O'),
#   ('hay', 'AUX', 'O'),
#   ('tres', 'NUM', 'O'),
#   ('heridos', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('carrera', 'NOUN', 'B-loc'),
#   ('15', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('79', 'NUM', 'I-loc'),
#   ('en', 'ADP', 'O'),
#   ('Chapinero', 'PROPN', 'B-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('Los', 'DET', 'O'),
#   ('fuertes', 'ADJ', 'O'),
#   ('vientos', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('según', 'ADP', 'O'),
#   ('las', 'DET', 'O'),
#   ('autoridades', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('generaron', 'VERB', 'O'),
#   ('la', 'DET', 'O'),
#   ('emergencia', 'NOUN', 'O'),
#   ('dejando', 'VERB', 'O'),
#   ('dos', 'NUM', 'O'),
#   ('personas', 'NOUN', 'O'),
#   ('atrapadas', 'ADJ', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('En', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Calle', 'PROPN', 'B-loc'),
#   ('34', 'NUM', 'I-loc'),
#   ('por', 'ADP', 'I-loc'),
#   ('17', 'NUM', 'I-loc'),
#   ('se', 'PRON', 'O'),
#   ('presentó', 'VERB', 'O'),
#   ('un', 'DET', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('motociclista', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('un', 'DET', 'O'),
#   ('vehículo', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('servicio', 'NOUN', 'O'),
#   ('público', 'ADJ', 'O'),
#   (';', 'PUNCT', 'O'),
#   ('conductor', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('motocicleta', 'NOUN', 'O'),
#   ('resulta', 'VERB', 'O'),
#   ('lesionado', 'ADJ', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('es', 'AUX', 'O'),
#   ('trasladado', 'VERB', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('movilidad', 'NOUN', 'O'),
#   ('Accidente', 'PROPN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('vehículos', 'NOUN', 'O'),
#   ('particulares', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('26', 'NUM', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('a', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('altura', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('estación', 'NOUN', 'B-loc'),
#   ('transmilenio', 'ADJ', 'I-loc'),
#   ('Normandía', 'PROPN', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('occidente', 'ADJ', 'O'),
#   ('-', 'PUNCT', 'O'),
#   ('Oriente', 'PROPN', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('noticia', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('desarrollo', 'NOUN', 'O')],
#  [('Accidente', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('Moto', 'PROPN', 'O'),
#   ('Av', 'PROPN', 'B-loc'),
#   ('Cali', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('Calle', 'PROPN', 'I-loc'),
#   ('13', 'NUM', 'I-loc'),
#   ('Bogotá', 'PROPN', 'O'),
#   ('Colombia', 'PROPN', 'O'),
#   ('vía', 'ADP', 'O'),
#   ('youtube', 'NOUN', 'O')],
#  [('sectormovilidad', 'NOUN', 'O'),
#   ('más', 'ADV', 'O'),
#   ('de', 'ADP', 'O'),
#   ('10', 'NUM', 'O'),
#   ('minutos', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('Av', 'PROPN', 'B-loc'),
#   ('Boyacá', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('127', 'NUM', 'I-loc'),
#   ('ya', 'ADV', 'O'),
#   ('llegó', 'VERB', 'O'),
#   ('la', 'DET', 'O'),
#   ('ambulancia', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('ningún', 'DET', 'O'),
#   ('policía', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('tránsito', 'NOUN', 'O'),
#   ('se', 'PRON', 'O'),
#   ('ha', 'AUX', 'O'),
#   ('reportado', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('sitio', 'NOUN', 'O')],
#  [('Aut', 'NOUN', 'B-loc'),
#   ('norte', 'NOUN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('128', 'NUM', 'I-loc'),
#   ('a', 'ADP', 'I-loc'),
#   ('choque', 'NOUN', 'O'),
#   ('simple', 'ADJ', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('2', 'NUM', 'O'),
#   ('taxis', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('Sentido', 'VERB', 'O'),
#   ('norte', 'NOUN', 'O'),
#   ('sur', 'ADJ', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('carril', 'NOUN', 'O'),
#   ('lento', 'ADJ', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('politransito', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('sitio', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('trafico', 'ADJ', 'O'),
#   ('lento', 'ADJ', 'O'),
#   ('por', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('carril', 'NOUN', 'O')],
#  [('citynoticias', 'NOUN', 'O'),
#   ('Grave', 'ADJ', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('tres', 'NUM', 'O'),
#   ('heridos', 'NOUN', 'O'),
#   ('ocurrió', 'VERB', 'O'),
#   ('esta', 'DET', 'O'),
#   ('tarde', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('63', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('carrera', 'NOUN', 'I-loc'),
#   ('50', 'NUM', 'I-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('El', 'DET', 'O'),
#   ('choque', 'NOUN', 'O'),
#   ('fue', 'AUX', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('taxi', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('una', 'DET', 'O'),
#   ('camioneta', 'NOUN', 'O')],
#  [('sectormovilidad', 'NOUN', 'O'),
#   ('accidente', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('3', 'NUM', 'O'),
#   ('carros', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('las', 'DET', 'O'),
#   ('Américas', 'PROPN', 'B-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('carrera', 'NOUN', 'I-loc'),
#   ('29', 'NUM', 'I-loc'),
#   ('tiene', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('tremendo', 'ADJ', 'O'),
#   ('caos', 'NOUN', 'O'),
#   ('las', 'DET', 'O'),
#   ('calles', 'NOUN', 'O'),
#   ('del', 'ADP', 'O'),
#   ('sector', 'NOUN', 'O'),
#   ('favor', 'NOUN', 'O'),
#   ('enviar', 'VERB', 'O'),
#   ('policía', 'NOUN', 'O')],
#  [('citynoticias', 'NOUN', 'O'),
#   ('fds', 'NOUN', 'O'),
#   ('Durante', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('madrugada', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('este', 'DET', 'O'),
#   ('domingo', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('un', 'DET', 'O'),
#   ('ciclista', 'NOUN', 'O'),
#   ('fue', 'AUX', 'O'),
#   ('embestido', 'VERB', 'O'),
#   ('por', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('taxista', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('al', 'ADP', 'O'),
#   ('parecer', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('por', 'ADP', 'O'),
#   ('exceso', 'NOUN', 'O'),
#   ('de', 'ADP', 'O'),
#   ('velocidad', 'NOUN', 'O'),
#   (',', 'PUNCT', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('calle', 'NOUN', 'B-loc'),
#   ('72', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('carrera', 'NOUN', 'I-loc'),
#   ('24', 'NUM', 'I-loc'),
#   ('.', 'PUNCT', 'O')],
#  [('colision', 'NOUN', 'O'),
#   ('entre', 'ADP', 'O'),
#   ('particular', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('bus', 'NOUN', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('carrera', 'NOUN', 'B-loc'),
#   ('7', 'NUM', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'NOUN', 'I-loc'),
#   ('72', 'NUM', 'I-loc'),
#   (',', 'PUNCT', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('sur-norte', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O')],
#  [('Señores', 'INTJ', 'O'),
#   ('bogotatransito', 'ADJ', 'O'),
#   ('hay', 'AUX', 'O'),
#   ('una', 'DET', 'O'),
#   ('estrellada', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('el', 'DET', 'O'),
#   ('puente', 'NOUN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('las', 'DET', 'I-loc'),
#   ('Américas', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('Carrera', 'PROPN', 'I-loc'),
#   ('30', 'NUM', 'I-loc'),
#   ('entre', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('SITP', 'PROPN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('una', 'DET', 'O'),
#   ('camioneta', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('No', 'ADV', 'O'),
#   ('hay', 'AUX', 'O'),
#   ('paso', 'NOUN', 'O'),
#   ('y', 'CCONJ', 'O'),
#   ('se', 'PRON', 'O'),
#   ('genera', 'VERB', 'O'),
#   ('una', 'DET', 'O'),
#   ('gran', 'ADJ', 'O'),
#   ('congestión', 'NOUN', 'O')],
#  [('*', 'SYM', 'O'),
#   ('Accidentes', 'NOUN', 'O'),
#   ('con', 'ADP', 'O'),
#   ('lesiones', 'NOUN', 'O'),
#   ('*', 'SYM', 'O'),
#   ('Por', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('avenida', 'NOUN', 'B-loc'),
#   ('Boyacá', 'PROPN', 'I-loc'),
#   ('con', 'ADP', 'I-loc'),
#   ('calle', 'PROPN', 'I-loc'),
#   ('53', 'NUM', 'I-loc'),
#   ('en', 'ADP', 'O'),
#   ('sentido', 'NOUN', 'O'),
#   ('norte', 'ADJ', 'O'),
#   ('-', 'PUNCT', 'O'),
#   ('sur', 'NOUN', 'O'),
#   ('un', 'DET', 'O'),
#   ('vehículo', 'NOUN', 'O'),
#   ('particular', 'ADJ', 'O'),
#   ('embiste', 'VERB', 'O'),
#   ('a', 'ADP', 'O'),
#   ('un', 'DET', 'O'),
#   ('ciclista', 'NOUN', 'O')],
#  [('Esta', 'DET', 'O'),
#   ('mañana', 'NOUN', 'B-time'),
#   ('a', 'ADP', 'O'),
#   ('las', 'DET', 'O'),
#   ('5:30', 'NUM', 'B-time'),
#   ('a.m', 'NOUN', 'I-time'),
#   ('me', 'PRON', 'O'),
#   ('tocó', 'VERB', 'O'),
#   ('un', 'DET', 'O'),
#   ('trancón', 'NOUN', 'O'),
#   ('por', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('variante', 'NOUN', 'B-loc'),
#   ('de', 'ADP', 'I-loc'),
#   ('fontibón', 'NOUN', 'I-loc'),
#   ('.', 'PUNCT', 'O'),
#   ('La', 'DET', 'O'),
#   ('causa', 'NOUN', 'O'),
#   (':', 'PUNCT', 'O'),
#   ('un', 'DET', 'O'),
#   ('ciclista', 'NOUN', 'O'),
#   ('muerto', 'ADJ', 'O'),
#   ('en', 'ADP', 'O'),
#   ('uno', 'PRON', 'O'),
#   ('de', 'ADP', 'O'),
#   ('los', 'DET', 'O'),
#   ('carriles', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('Un', 'DET', 'O'),
#   ('muchacho', 'NOUN', 'O'),
#   ('joven', 'ADJ', 'O'),
#   ('.', 'PUNCT', 'O'),
#   ('De', 'ADP', 'O'),
#   ('esos', 'DET', 'O'),
#   ('que', 'PRON', 'O'),
#   ('salen', 'VERB', 'O'),
#   ('a', 'ADP', 'O'),
#   ('trabajar', 'VERB', 'O'),
#   ('en', 'ADP', 'O'),
#   ('la', 'DET', 'O'),
#   ('madrugada', 'NOUN', 'O'),
#   ('.', 'PUNCT', 'O')]]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %%
X
# Out:
# [[{'bias': 1.0,
#    'word.lower()': 'sectormovilidad',
#    'word[-3:]': 'dad',
#    'word[-2:]': 'ad',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    'BOS': True,
#    '+1:word.lower()': 'giro',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'giro',
#    'word[-3:]': 'iro',
#    'word[-2:]': 'ro',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'sectormovilidad',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'paa',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'paa',
#    'word[-3:]': 'paa',
#    'word[-2:]': 'aa',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'giro',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'tomar',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VERB',
#    '+1:postag[:2]': 'VE'},
#   {'bias': 1.0,
#    'word.lower()': 'tomar',
#    'word[-3:]': 'mar',
#    'word[-2:]': 'ar',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VERB',
#    'postag[:2]': 'VE',
#    '-1:word.lower()': 'paa',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'la',
#    'word[-2:]': 'la',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'tomar',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VERB',
#    '-1:postag[:2]': 'VE',
#    '+1:word.lower()': 'calle',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'calle',
#    'word[-3:]': 'lle',
#    'word[-2:]': 'le',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': '80',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NUM',
#    '+1:postag[:2]': 'NU'},
#   {'bias': 1.0,
#    'word.lower()': '80',
#    'word[-3:]': '80',
#    'word[-2:]': '80',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': True,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    '-1:word.lower()': 'calle',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'al',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'al',
#    'word[-3:]': 'al',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': '80',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    '+1:word.lower()': 'occidente',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'occidente',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'al',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'en',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'en',
#    'word[-3:]': 'en',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'occidente',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'av',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'av',
#    'word[-3:]': 'av',
#    'word[-2:]': 'av',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'en',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'boyaca',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PROPN',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'boyaca',
#    'word[-3:]': 'aca',
#    'word[-2:]': 'ca',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PROPN',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'av',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'bloqueado',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'bloqueado',
#    'word[-3:]': 'ado',
#    'word[-2:]': 'do',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'boyaca',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PROPN',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'por',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'por',
#    'word[-3:]': 'por',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'bloqueado',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'accidente',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'accidente',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'por',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'simple',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'simple',
#    'word[-3:]': 'ple',
#    'word[-2:]': 'le',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'accidente',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': ',',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': ',',
#    'word[-3:]': ',',
#    'word[-2:]': ',',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'simple',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'paso',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'paso',
#    'word[-3:]': 'aso',
#    'word[-2:]': 'so',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': ',',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'bloqueado',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'bloqueado',
#    'word[-3:]': 'ado',
#    'word[-2:]': 'do',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'paso',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word.lower()': 'sectormovilidad',
#    'word[-3:]': 'dad',
#    'word[-2:]': 'ad',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    'BOS': True,
#    '+1:word.lower()': 'hubo',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'AUX',
#    '+1:postag[:2]': 'AU'},
#   {'bias': 1.0,
#    'word.lower()': 'hubo',
#    'word[-3:]': 'ubo',
#    'word[-2:]': 'bo',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'AUX',
#    'postag[:2]': 'AU',
#    '-1:word.lower()': 'sectormovilidad',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'un',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'un',
#    'word[-3:]': 'un',
#    'word[-2:]': 'un',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'hubo',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'AUX',
#    '-1:postag[:2]': 'AU',
#    '+1:word.lower()': 'choque',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'choque',
#    'word[-3:]': 'que',
#    'word[-2:]': 'ue',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'un',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'entre',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'entre',
#    'word[-3:]': 'tre',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'choque',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'un',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'un',
#    'word[-3:]': 'un',
#    'word[-2:]': 'un',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'entre',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'sitp',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'sitp',
#    'word[-3:]': 'itp',
#    'word[-2:]': 'tp',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'un',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'y',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CCONJ',
#    '+1:postag[:2]': 'CC'},
#   {'bias': 1.0,
#    'word.lower()': 'y',
#    'word[-3:]': 'y',
#    'word[-2:]': 'y',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CCONJ',
#    'postag[:2]': 'CC',
#    '-1:word.lower()': 'sitp',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'una',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'una',
#    'word[-3:]': 'una',
#    'word[-2:]': 'na',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'y',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CCONJ',
#    '-1:postag[:2]': 'CC',
#    '+1:word.lower()': 'camioneta',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'camioneta',
#    'word[-3:]': 'eta',
#    'word[-2:]': 'ta',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'una',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': ',',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': ',',
#    'word[-3:]': ',',
#    'word[-2:]': ',',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'camioneta',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'en',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'en',
#    'word[-3:]': 'en',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': ',',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'la',
#    'word[-2:]': 'la',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'en',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'oreja',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'oreja',
#    'word[-3:]': 'eja',
#    'word[-2:]': 'ja',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'oreja',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'la',
#    'word[-2:]': 'la',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': '68',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': '68',
#    'word[-3:]': '68',
#    'word[-2:]': '68',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': True,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'que',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRON',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'que',
#    'word[-3:]': 'que',
#    'word[-2:]': 'ue',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PRON',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': '68',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'sale',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VERB',
#    '+1:postag[:2]': 'VE'},
#   {'bias': 1.0,
#    'word.lower()': 'sale',
#    'word[-3:]': 'ale',
#    'word[-2:]': 'le',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VERB',
#    'postag[:2]': 'VE',
#    '-1:word.lower()': 'que',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRON',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'a',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'a',
#    'word[-3:]': 'a',
#    'word[-2:]': 'a',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'sale',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VERB',
#    '-1:postag[:2]': 'VE',
#    '+1:word.lower()': 'las',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'las',
#    'word[-3:]': 'las',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'a',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': '26',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NUM',
#    '+1:postag[:2]': 'NU'},
#   {'bias': 1.0,
#    'word.lower()': '26',
#    'word[-3:]': '26',
#    'word[-2:]': '26',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': True,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    '-1:word.lower()': 'las',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'hacia',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'hacia',
#    'word[-3:]': 'cia',
#    'word[-2:]': 'ia',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': '26',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    '+1:word.lower()': 'el',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'el',
#    'word[-3:]': 'el',
#    'word[-2:]': 'el',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'hacia',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'occidente',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'occidente',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'el',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': ',',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': ',',
#    'word[-3:]': ',',
#    'word[-2:]': ',',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'occidente',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'tienen',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VERB',
#    '+1:postag[:2]': 'VE'},
#   {'bias': 1.0,
#    'word.lower()': 'tienen',
#    'word[-3:]': 'nen',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VERB',
#    'postag[:2]': 'VE',
#    '-1:word.lower()': ',',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'todo',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'todo',
#    'word[-3:]': 'odo',
#    'word[-2:]': 'do',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'tienen',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VERB',
#    '-1:postag[:2]': 'VE',
#    '+1:word.lower()': 'el',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'el',
#    'word[-3:]': 'el',
#    'word[-2:]': 'el',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'todo',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'tráfico',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'tráfico',
#    'word[-3:]': 'ico',
#    'word[-2:]': 'co',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'el',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'retenido',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'retenido',
#    'word[-3:]': 'ido',
#    'word[-2:]': 'do',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'tráfico',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': ',',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': ',',
#    'word[-3:]': ',',
#    'word[-2:]': ',',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'retenido',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'hay',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'AUX',
#    '+1:postag[:2]': 'AU'},
#   {'bias': 1.0,
#    'word.lower()': 'hay',
#    'word[-3:]': 'hay',
#    'word[-2:]': 'ay',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'AUX',
#    'postag[:2]': 'AU',
#    '-1:word.lower()': ',',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'una',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'una',
#    'word[-3:]': 'una',
#    'word[-2:]': 'na',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'hay',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'AUX',
#    '-1:postag[:2]': 'AU',
#    '+1:word.lower()': 'ambulancia',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'ambulancia',
#    'word[-3:]': 'cia',
#    'word[-2:]': 'ia',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'una',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': '!!',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': '!!',
#    'word[-3:]': '!!',
#    'word[-2:]': '!!',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'ambulancia',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word.lower()': '2',
#    'word[-3:]': '2',
#    'word[-2:]': '2',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': True,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    'BOS': True,
#    '+1:word.lower()': 'ciclistas',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'ciclistas',
#    'word[-3:]': 'tas',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': '2',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    '+1:word.lower()': 'muertos',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'muertos',
#    'word[-3:]': 'tos',
#    'word[-2:]': 'os',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'ciclistas',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'hoy',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADV',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'hoy',
#    'word[-3:]': 'hoy',
#    'word[-2:]': 'oy',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADV',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'muertos',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'hoy',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADV',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': '5:30',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NUM',
#    '+1:postag[:2]': 'NU'},
#   {'bias': 1.0,
#    'word.lower()': '5:30',
#    'word[-3:]': ':30',
#    'word[-2:]': '30',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'am',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'am',
#    'word[-3:]': 'am',
#    'word[-2:]': 'am',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': '5:30',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    '+1:word.lower()': 'a',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'a',
#    'word[-3:]': 'a',
#    'word[-2:]': 'a',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'am',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': '9:45',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NUM',
#    '+1:postag[:2]': 'NU'},
#   {'bias': 1.0,
#    'word.lower()': '9:45',
#    'word[-3:]': ':45',
#    'word[-2:]': '45',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    '-1:word.lower()': 'a',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'am',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'am',
#    'word[-3:]': 'am',
#    'word[-2:]': 'am',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': '9:45',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    '+1:word.lower()': 'en',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'en',
#    'word[-3:]': 'en',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'am',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'el',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'el',
#    'word[-3:]': 'el',
#    'word[-2:]': 'el',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'en',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'corto',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'corto',
#    'word[-3:]': 'rto',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'el',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'tramo',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'tramo',
#    'word[-3:]': 'amo',
#    'word[-2:]': 'mo',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'corto',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'tramo',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'puente',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'puente',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'guaduas',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'guaduas',
#    'word[-3:]': 'uas',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'puente',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'al',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'al',
#    'word[-3:]': 'al',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'guaduas',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'puente',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'puente',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'al',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'puente',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'la',
#    'word[-2:]': 'la',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'rotonda',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'rotonda',
#    'word[-3:]': 'nda',
#    'word[-2:]': 'da',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'rotonda',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'siberia',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PROPN',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'siberia',
#    'word[-3:]': 'ria',
#    'word[-2:]': 'ia',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PROPN',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'siberia',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PROPN',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'este',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'este',
#    'word[-3:]': 'ste',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'año',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'año',
#    'word[-3:]': 'año',
#    'word[-2:]': 'ño',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'este',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'en',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'en',
#    'word[-3:]': 'en',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'año',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'ese',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'ese',
#    'word[-3:]': 'ese',
#    'word[-2:]': 'se',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'en',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'mismo',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'mismo',
#    'word[-3:]': 'smo',
#    'word[-2:]': 'mo',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'ese',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'tramo',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'tramo',
#    'word[-3:]': 'amo',
#    'word[-2:]': 'mo',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'mismo',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'van',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VERB',
#    '+1:postag[:2]': 'VE'},
#   {'bias': 1.0,
#    'word.lower()': 'van',
#    'word[-3:]': 'van',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VERB',
#    'postag[:2]': 'VE',
#    '-1:word.lower()': 'tramo',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'por',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'por',
#    'word[-3:]': 'por',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'van',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VERB',
#    '-1:postag[:2]': 'VE',
#    '+1:word.lower()': 'poquito',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRON',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'poquito',
#    'word[-3:]': 'ito',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PRON',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'por',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': '10',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NUM',
#    '+1:postag[:2]': 'NU'},
#   {'bias': 1.0,
#    'word.lower()': '10',
#    'word[-3:]': '10',
#    'word[-2:]': '10',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': True,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    '-1:word.lower()': 'poquito',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRON',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'ciclistas',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'ciclistas',
#    'word[-3:]': 'tas',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': '10',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    '+1:word.lower()': 'muertos',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'muertos',
#    'word[-3:]': 'tos',
#    'word[-2:]': 'os',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'ciclistas',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'por',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'por',
#    'word[-3:]': 'por',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'muertos',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'accidente',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'accidente',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'por',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': ',',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': ',',
#    'word[-3:]': ',',
#    'word[-2:]': ',',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'accidente',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'delicado',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'delicado',
#    'word[-3:]': 'ado',
#    'word[-2:]': 'do',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': ',',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'ese',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'ese',
#    'word[-3:]': 'ese',
#    'word[-2:]': 'se',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
# ...
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'por',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'por',
#    'word[-3:]': 'por',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'trancón',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'la',
#    'word[-2:]': 'la',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'por',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'variante',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'variante',
#    'word[-3:]': 'nte',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'variante',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'fontibón',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'fontibón',
#    'word[-3:]': 'bón',
#    'word[-2:]': 'ón',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'fontibón',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'La',
#    'word[-2:]': 'La',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'causa',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'causa',
#    'word[-3:]': 'usa',
#    'word[-2:]': 'sa',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': ':',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': ':',
#    'word[-3:]': ':',
#    'word[-2:]': ':',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'causa',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'un',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'un',
#    'word[-3:]': 'un',
#    'word[-2:]': 'un',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': ':',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'ciclista',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'ciclista',
#    'word[-3:]': 'sta',
#    'word[-2:]': 'ta',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'un',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'muerto',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'muerto',
#    'word[-3:]': 'rto',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'ciclista',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'en',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'en',
#    'word[-3:]': 'en',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'muerto',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'uno',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRON',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'uno',
#    'word[-3:]': 'uno',
#    'word[-2:]': 'no',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PRON',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'en',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'de',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'uno',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRON',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'los',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'los',
#    'word[-3:]': 'los',
#    'word[-2:]': 'os',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'carriles',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'carriles',
#    'word[-3:]': 'les',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'los',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'carriles',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': 'un',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'un',
#    'word[-3:]': 'Un',
#    'word[-2:]': 'Un',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'muchacho',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'muchacho',
#    'word[-3:]': 'cho',
#    'word[-2:]': 'ho',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'un',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'joven',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADJ',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'joven',
#    'word[-3:]': 'ven',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADJ',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'muchacho',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'joven',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADJ',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'de',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'de',
#    'word[-3:]': 'De',
#    'word[-2:]': 'De',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PUNCT',
#    '-1:postag[:2]': 'PU',
#    '+1:word.lower()': 'esos',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'esos',
#    'word[-3:]': 'sos',
#    'word[-2:]': 'os',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'de',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'que',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRON',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'que',
#    'word[-3:]': 'que',
#    'word[-2:]': 'ue',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PRON',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'esos',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': 'salen',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VERB',
#    '+1:postag[:2]': 'VE'},
#   {'bias': 1.0,
#    'word.lower()': 'salen',
#    'word[-3:]': 'len',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VERB',
#    'postag[:2]': 'VE',
#    '-1:word.lower()': 'que',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRON',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'a',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'a',
#    'word[-3:]': 'a',
#    'word[-2:]': 'a',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'salen',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VERB',
#    '-1:postag[:2]': 'VE',
#    '+1:word.lower()': 'trabajar',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VERB',
#    '+1:postag[:2]': 'VE'},
#   {'bias': 1.0,
#    'word.lower()': 'trabajar',
#    'word[-3:]': 'jar',
#    'word[-2:]': 'ar',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VERB',
#    'postag[:2]': 'VE',
#    '-1:word.lower()': 'a',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'en',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ADP',
#    '+1:postag[:2]': 'AD'},
#   {'bias': 1.0,
#    'word.lower()': 'en',
#    'word[-3:]': 'en',
#    'word[-2:]': 'en',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ADP',
#    'postag[:2]': 'AD',
#    '-1:word.lower()': 'trabajar',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VERB',
#    '-1:postag[:2]': 'VE',
#    '+1:word.lower()': 'la',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DET',
#    '+1:postag[:2]': 'DE'},
#   {'bias': 1.0,
#    'word.lower()': 'la',
#    'word[-3:]': 'la',
#    'word[-2:]': 'la',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DET',
#    'postag[:2]': 'DE',
#    '-1:word.lower()': 'en',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ADP',
#    '-1:postag[:2]': 'AD',
#    '+1:word.lower()': 'madrugada',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NOUN',
#    '+1:postag[:2]': 'NO'},
#   {'bias': 1.0,
#    'word.lower()': 'madrugada',
#    'word[-3:]': 'ada',
#    'word[-2:]': 'da',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NOUN',
#    'postag[:2]': 'NO',
#    '-1:word.lower()': 'la',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DET',
#    '-1:postag[:2]': 'DE',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PUNCT',
#    '+1:postag[:2]': 'PU'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    '-1:word.lower()': 'madrugada',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NOUN',
#    '-1:postag[:2]': 'NO',
#    'EOS': True}]]

# %% [markdown]
# ## Model CRF
# Now we can initialize the algorithm. We use the conditional random field (CRF) implementation provided by sklearn-crfsuite.

# %%
from sklearn_crfsuite import CRF
from sklearn.model_selection import cross_val_predict
from sklearn_crfsuite.metrics import flat_classification_report
import eli5

# %%
from sklearn_crfsuite import CRF

crf = CRF(algorithm='lbfgs',
          c1=0.1,
          c2=0.1,
          max_iterations=100,
          all_possible_transitions=False)

# %%
pred = cross_val_predict(estimator=crf, X=X, y=y, cv=5)

# %%
report = flat_classification_report(y_pred=pred, y_true=y)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        B-loc       0.74      0.55      0.63        62
#       B-time       0.00      0.00      0.00         8
#        I-loc       0.85      0.74      0.80       180
#       I-time       0.00      0.00      0.00         8
#            O       0.92      0.98      0.95       954
#
#     accuracy                           0.91      1212
#    macro avg       0.50      0.45      0.47      1212
# weighted avg       0.89      0.91      0.90      1212
# /home/hat/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
crf.fit(X, y)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-loc</th>
#
#                 <th>I-loc</th>
#
#                 <th>B-time</th>
#
#                 <th>I-time</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.65%)" title="O &rArr; O">
#                             3.694
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 84.64%)" title="O &rArr; B-loc">
#                             3.102
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.55%)" title="O &rArr; B-time">
#                             1.322
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-loc</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 89.50%)" title="B-loc &rArr; O">
#                             -1.802
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.55%)" title="B-loc &rArr; I-loc">
#                             4.348
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-loc</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.42%)" title="I-loc &rArr; O">
#                             0.029
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="I-loc &rArr; I-loc">
#                             4.525
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-time</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.53%)" title="B-time &rArr; O">
#                             -0.228
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; I-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.48%)" title="B-time &rArr; B-time">
#                             0.234
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.78%)" title="B-time &rArr; I-time">
#                             1.272
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-time</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.65%)" title="I-time &rArr; O">
#                             -0.512
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; I-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.95%)" title="I-time &rArr; I-time">
#                             2.732
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-loc
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-loc
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-time
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-time
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>

# %% [markdown]
# ### Improve the model with regularization

# %%
crf = CRF(algorithm='lbfgs',
c1=10,
c2=0.1,
max_iterations=100,
all_possible_transitions=False)

# %%
pred = cross_val_predict(estimator=crf, X=X, y=y, cv=5)

# %%
report = flat_classification_report(y_pred=pred, y_true=y)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        B-loc       0.85      0.27      0.41        62
#       B-time       0.00      0.00      0.00         8
#        I-loc       0.86      0.35      0.50       180
#       I-time       0.00      0.00      0.00         8
#            O       0.84      0.99      0.91       954
#
#     accuracy                           0.84      1212
#    macro avg       0.51      0.32      0.36      1212
# weighted avg       0.84      0.84      0.81      1212

# %%
crf.fit(X, y)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=10, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-loc</th>
#
#                 <th>I-loc</th>
#
#                 <th>B-time</th>
#
#                 <th>I-time</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.89%)" title="O &rArr; O">
#                             2.136
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.69%)" title="O &rArr; B-loc">
#                             0.83
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-loc</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="B-loc &rArr; I-loc">
#                             2.909
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-loc &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-loc</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.28%)" title="I-loc &rArr; I-loc">
#                             2.646
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-loc &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-time</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; I-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-time &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-time</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; B-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; I-loc">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; B-time">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-time &rArr; I-time">
#                             0.0
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-loc
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-loc
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-time
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-time
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
