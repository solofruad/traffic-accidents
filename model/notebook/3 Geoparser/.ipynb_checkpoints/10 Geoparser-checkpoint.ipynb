# %% [markdown]
# # Geoparser with Address Normalization
# ### By **Néstor Suat** in 2021
#
# **Descripción:** Combinando `9 Agregando location` y `9 Address Normalization`.
# Se realiza normalización de direcciones usando librería en C `libpostal`
#
# Fuente: https://github.com/openvenues/libpostal

# %%
from postal.expand import expand_address
from ast import literal_eval

import pandas as pd
import re
import math

# %%
def add_location(entities):
    #print(entities)
    loc = [ t for (t,l) in entities  if l == 'loc' ]
    if len(loc) > 4: ## Descartar tweets con más de 4 entidades de ubicaciones reconocidas
        loc = ''    
    loc = ' '.join(loc)
    if len(loc.split(' ')) < 4:   ## Descartar Tweets con menos de 4 palabras     
        loc = ''
    return loc

def address_normalization(location):    
    expansions = expand_address(location, 
                                roman_numerals=False, 
                                split_alpha_from_numeric=True, 
                                expand_numex=False,
                                languages=["es"])
    if len(expansions) > 0:
        expansions = re.sub(r'\b(\w+)( \1\b)+', r'\1', expansions[-1])
        expansions = 'Bogota '+expansions
        expansions = removeWords(expansions.upper())
    else:
        expansions = ''
    return expansions

def removeWords(text):
    stopwords = ['CON','POR','Y']
    return ' '.join([word for word in text.split() if word not in stopwords])

# %% [markdown]
# ### Importando dataset

# %% [raw]
# entities_accident_1_server_bogota -- 5832 tweets
# entities_accident_2_server_token_search -- 60970 tweets
# entities_accident_3_server_token_user -- 50111 tweets
# entities_accident_4_server_follow_timeline_user -- 87241 tweets

# %%
## Variables para importar modelos y demás
#dir_ = "../../data/v1/NER/src/prueba_bad_location/"
#dir_ = "../../data/v1/NER/src/prueba_ok_location/"
#dir_ = "../../data/v1/NER/"
dir_ = "../../data/database/output_ml/M1/NER_extractor/"

#file = 'ner_dataset_test_ok.tsv' # Dataset
file = 'entities_accident_4_server_follow_timeline_user.tsv'

# %%
## Importando Dataset
dataset = pd.read_csv(dir_+file, delimiter = "\t", quoting = 3)
#del dataset['Unnamed: 0']
#del dataset['gmap']
print(dataset.shape)
dataset.head(5)
# Out:
# (87271, 27)
#                         _id            api coordinates           created_at  \
# 0  5bbc1901dc5d3f22d9c38821  Stream-follow          {}  2018-10-08 21:57:04
# 1  5bbc192adc5d3f22d9c38829  Stream-follow          {}  2018-10-08 21:57:46
# 2  5bbc243fdc5d3f2354ac637a  Stream-follow          {}  2018-10-08 22:45:03
# 3  5bbc292bdc5d3f2580132dee  Stream-follow          {}  2018-10-08 23:06:03
# 4  5bbc2adcdc5d3f2580132dfa  Stream-follow          {}  2018-10-08 23:13:16
#
#         created_at_str  favorite_count geo             id_tweet  \
# 0  2018-10-09 02:57:04               0  {}  1049493924291727360
# 1  2018-10-09 02:57:46               0  {}  1049494097998880769
# 2  2018-10-09 03:45:03               0  {}  1049505997600055296
# 3  2018-10-09 04:06:03               0  {}  1049511282624335872
# 4  2018-10-09 04:13:16               0  {}  1049513098774765568
#
#   place_coordinates place_country  ...             user_id user_listed_count  \
# 0                {}           NaN  ...            91371148                45
# 1                {}           NaN  ...            66509310                12
# 2                {}           NaN  ...  985956584655290391                 0
# 3                {}           NaN  ...          4114754413                 1
# 4                {}           NaN  ...           141597111                 4
#
#                     user_location     user_name  \
# 0                             NaN      Isgarvan
# 1         Bogotá D.C. - Colombia.     ndelapava
# 2                             NaN    K940223593
# 3  Seachells Islands Indian Ocean      lp972039
# 4                         Bogota   lordviktor23
#
#                               user_profile_image_url  user_statuses_count  \
# 0  http://pbs.twimg.com/profile_images/6921179185...                56478
# 1  http://pbs.twimg.com/profile_images/9940267761...                22065
# 2  http://pbs.twimg.com/profile_images/1013532920...                 5712
# 3  http://pbs.twimg.com/profile_images/8955346283...                   74
# 4  http://pbs.twimg.com/profile_images/1031371042...                10261
#
#    user_verified  label                                              clean  \
# 0          False      1  RT citytv : citynoticias Otro accidente regist...
# 1          False      1  RT citytv : citynoticias Otro accidente regist...
# 2          False      1  RT citytv : citynoticias Otro accidente regist...
# 3          False      1  citytv Dejen tanto consentir machos hay sicari...
# 4          False      1  RT citytv : citynoticias Otro accidente regist...
#
#                          entities
# 0  [('localidad de Bosa', 'loc')]
# 1  [('localidad de Bosa', 'loc')]
# 2  [('localidad de Bosa', 'loc')]
# 3              [('calle', 'loc')]
# 4  [('localidad de Bosa', 'loc')]
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Eliminar tweets sin entidades reconocidas

# %%
dataset = dataset[dataset['entities']!='[]']
dataset = dataset.reset_index(drop=True)
dataset.shape
# Out:
# (85077, 27)

# %%
#Conversión de tweets
dataset.entities = dataset.entities.apply(literal_eval)

# %%
#Conversión de entities loc a una dirección escrita
dataset['location'] = dataset.entities.apply(add_location)
dataset['location']
# Out:
# 0
# 1
# 2
# 3
# 4
#                      ...
# 85072            Av. Cali con Calle 91
# 85073          Calle 116 con Carrera 9
# 85074    Carrera 24 con Calle 41 A Sur
# 85075                 Cr 9 con Cll 140
# 85076          Carrera 68 con Calle 26
# Name: location, Length: 85077, dtype: object

# %%
### Descartar ubicaciones de tweets con menos de 4 palabras en su contenido
### Descartar ubicaciones de tweets con más de 4 entidades de ubicación reconocidad.
dataset = dataset[dataset['location']!='']
dataset = dataset.reset_index(drop=True)
dataset.shape
# Out:
# (80277, 28)

# %% [markdown]
# ## Addresss Normalization
# * Usando librería en C `libpostal`

# %%
dataset['address_normalization'] = dataset.location.apply(address_normalization)
dataset['address_normalization']
# Out:
# 0        BOGOTA AVENIDA CARRERA 9 CALLE 139 SNUNIDAD TR...
# 1        BOGOTA AVENIDA PRIMERO DE MAYO CARRERA 50 GLOR...
# 2                      BOGOTA TRANSVERSAL 51 DIAGONAL 48 F
# 3        BOGOTA AVENIDA CIUDAD DE VILLAVICENCIO CALLE 5...
# 4                             BOGOTA CARRERA 50 CALLE 18 A
#                                ...
# 80272               BOGOTA AVENIDA CIUDAD DE CALI CALLE 91
# 80273           BOGOTA AVENIDA CALLE 116 AVENIDA CARRERA 9
# 80274             BOGOTA AVENIDA CARRERA 24 CALLE 41 A SUR
# 80275                   BOGOTA AVENIDA CARRERA 9 CALLE 140
# 80276           BOGOTA AVENIDA CARRERA 68 AVENIDA CALLE 26
# Name: address_normalization, Length: 80277, dtype: object

# %%
dataset = dataset[dataset['address_normalization']!='']
dataset = dataset.reset_index(drop=True)
dataset.shape
# Out:
# (80277, 29)

# %%
dataset.to_csv(dir_+"norm_"+file,sep='\t',index=False)

# %% [markdown]
# ### Generando para Geocoding

# %%
locations = []
for i in range(len(dataset)):
    loc = []
    #norm = 'Bogota '+dataset.iloc[i]['address_normalization']
    #norm = removeWords(norm.upper())
    loc += [dataset.iloc[i]['address_normalization']] + ['CO']
    locations.append(loc)
#locations

# %%
df = pd.DataFrame(locations,columns=['address','iso2'])
#df.rename(columns={0:'address',1:''}, inplace=True)
df
# Out:
#                                                  address iso2
# 0      BOGOTA AVENIDA CARRERA 9 CALLE 139 SNUNIDAD TR...   CO
# 1      BOGOTA AVENIDA PRIMERO DE MAYO CARRERA 50 GLOR...   CO
# 2                    BOGOTA TRANSVERSAL 51 DIAGONAL 48 F   CO
# 3      BOGOTA AVENIDA CIUDAD DE VILLAVICENCIO CALLE 5...   CO
# 4                           BOGOTA CARRERA 50 CALLE 18 A   CO
# ...                                                  ...  ...
# 80272             BOGOTA AVENIDA CIUDAD DE CALI CALLE 91   CO
# 80273         BOGOTA AVENIDA CALLE 116 AVENIDA CARRERA 9   CO
# 80274           BOGOTA AVENIDA CARRERA 24 CALLE 41 A SUR   CO
# 80275                 BOGOTA AVENIDA CARRERA 9 CALLE 140   CO
# 80276         BOGOTA AVENIDA CARRERA 68 AVENIDA CALLE 26   CO
#
# [80277 rows x 2 columns]

# %%
df.to_csv(dir_+'format_norm_'+file.split(".")[0]+".csv", index=False)

# %% [markdown]
# ## Formateando resultados de Batch Geocode con Addresss Normalization

# %%
batch_geocode = pd.read_csv(dir_+'geocode_results_2021_03_10.csv')
batch_geocode = batch_geocode[['best_lat','best_long']]
batch_geocode
# Out:
#       best_lat  best_long
# 0          NaN        NaN
# 1     4.634422 -74.096084
# 2     4.711552 -74.072544
# 3          NaN        NaN
# 4     4.660691 -74.074803
# ...        ...        ...
# 1331       NaN        NaN
# 1332       NaN        NaN
# 1333  4.603237 -74.153714
# 1334  4.721292 -74.091972
# 1335       NaN        NaN
#
# [1336 rows x 2 columns]

# %%
dataset['gmap'] = ''
for i in range(len(dataset)):
    if(not math.isnan(batch_geocode.iloc[i]['best_lat'])):
        dataset.at[i,'gmap'] = "{'lat': "+str(batch_geocode.iloc[i]['best_lat'])+", 'lng': "+str(batch_geocode.iloc[i]['best_long'])+"}"
    else:
        dataset.drop(index=dataset.index[[i]])

# %%
geocoding = dataset.copy()
geocoding
# Out:
#                  id_tweet                                               text  \
# 0     1047808970847604737  Rt Avenida Primero de Mayo frente al sena de l...
# 1     1047809516937596928  Rt *Accidente* Se presenta volcamiento de vehí...
# 2     1047809727118430210  Rt Av. Las villas norte al sur llegando a la 1...
# 3     1047821671854473216  Rt *Accidente*Se presenta siniestro vial entre...
# 4     1047843812977065985  Para peor tristeza, muerto en la Av. Cra. 30, ...
# ...                   ...                                                ...
# 1331   983339568723349505  Cra 7 NS alto aforo altura calle 134, tráfico ...
# 1332  1102902768514359296      Cra 7 NS tráfico lento desde calle 140 al sur
# 1333  1093845140983218184  CRA 80 X CL 45 SUR : Se presenta incidente via...
# 1334   979318808136560641  Carrera 91 calle 95 lesionado en accidente de ...
# 1335  1029706559293730821  Carrera 9a con 135 C ambulancia número 5999 at...
#
#               created_at        user_name     user_location  \
# 0     2018-10-04 6:21:40  camilogallardoa               NaN
# 1     2018-10-04 6:23:50  camilogallardoa               NaN
# 2     2018-10-04 6:24:40  camilogallardoa               NaN
# 3     2018-10-04 7:12:08  camilogallardoa               NaN
# 4     2018-10-04 8:40:07          capdiaz  Bogotá, Colombia
# ...                  ...              ...               ...
# 1331  2018-04-09 8:43:17      RedapBogota  Bogota, Colombia
# 1332  2019-03-05 7:04:45      RedapBogota  Bogota, Colombia
# 1333  2019-02-08 7:12:58      RedapBogota  Bogota, Colombia
# 1334  2018-03-29 6:26:13      RedapBogota  Bogota, Colombia
# 1335  2018-08-15 7:29:09      RedapBogota  Bogota, Colombia
#
#                       source  \
# 0              Search BOGOTA
# 1              Search BOGOTA
# 2              Search BOGOTA
# 3              Search BOGOTA
# 4              Search BOGOTA
# ...                      ...
# 1331  4_SEARCH TIMELINE USER
# 1332  4_SEARCH TIMELINE USER
# 1333  4_SEARCH TIMELINE USER
# 1334  4_SEARCH TIMELINE USER
# 1335  4_SEARCH TIMELINE USER
#
#                                                   clean  \
# 0     Rt Avenida Primero de Mayo frente al sena de l...
# 1     Rt *Accidente* Se presenta volcamiento de vehí...
# 2     Rt Av. Las villas norte al sur llegando a la 1...
# 3     Rt *Accidente*Se presenta siniestro vial entre...
# 4     Para peor tristeza, muerto en la Av. Cra. 30, ...
# ...                                                 ...
# 1331  Cra 7 NS alto aforo altura calle 134, tráfico ...
# 1332      Cra 7 NS tráfico lento desde calle 140 al sur
# 1333  CRA 80 X CL 45 SUR : Se presenta incidente via...
# 1334  Carrera 91 calle 95 lesionado en accidente de ...
# 1335  Carrera 9a con 135 C ambulancia número 5999 at...
#
#                                                entities  \
# 0     [(Avenida Primero de Mayo, loc), (sena, loc), ...
# 1               [(carrera 68 con la Av Esperanza, loc)]
# 2     [(Av. Las villas, loc), (la 127, loc), (buleva...
# 3                         [(Av. NQS con calle 67, loc)]
# 4                [(Av. Cra . 30, loc), (Calle 67, loc)]
# ...                                                 ...
# 1331                   [(Cra 7, loc), (calle 134, loc)]
# 1332                   [(Cra 7, loc), (calle 140, loc)]
# 1333                        [(CRA 80 X CL 45 SUR, loc)]
# 1334                       [(Carrera 91 calle 95, loc)]
# 1335                      [(Carrera 9a con 135 C, loc)]
#
#                                      location  \
# 0     Avenida Primero de Mayo sena carrera 30
# 1              carrera 68 con la Av Esperanza
# 2          Av. Las villas la 127 bulevar Niza
# 3                        Av. NQS con calle 67
# 4                       Av. Cra . 30 Calle 67
# ...                                       ...
# 1331                          Cra 7 calle 134
# 1332                          Cra 7 calle 140
# 1333                       CRA 80 X CL 45 SUR
# 1334                      Carrera 91 calle 95
# 1335                     Carrera 9a con 135 C
#
#                                   address_normalization  \
# 0     BOGOTA AVENIDA PRIMERO DE MAYO SENA AVENIDA CA...
# 1     BOGOTA AVENIDA CARRERA 68 LA AVENIDA DE LA ESP...
# 2         BOGOTA AVENIDA LAS VILLAS LA 127 BULEVAR NIZA
# 3                           BOGOTA AVENIDA NQS CALLE 67
# 4                    BOGOTA AVENIDA CARRERA 30 CALLE 67
# ...                                                 ...
# 1331           BOGOTA AVENIDA CARRERA SEPTIMA CALLE 134
# 1332           BOGOTA AVENIDA CARRERA SEPTIMA CALLE 140
# 1333     BOGOTA AVENIDA CARRERA 80 AVENIDA CALLE 45 SUR
# 1334                 BOGOTA AVENIDA CARRERA 91 CALLE 95
# 1335                     BOGOTA AVENIDA CARRERA 9 135 C
#
#                                                    gmap
# 0
# 1     {'lat': 4.634422233333333, 'lng': -74.09608436...
# 2         {'lat': 4.7115524, 'lng': -74.07254429999998}
# 3
# 4     {'lat': 4.660691244444443, 'lng': -74.07480312...
# ...                                                 ...
# 1331
# 1332
# 1333            {'lat': 4.6032374, 'lng': -74.15371445}
# 1334  {'lat': 4.721292066666667, 'lng': -74.09197183...
# 1335
#
# [1336 rows x 11 columns]

# %%
geocoding = geocoding[dataset['gmap']!='']
geocoding = geocoding.reset_index(drop=True)
geocoding
# Out:
#                 id_tweet                                               text  \
# 0    1047809516937596928  Rt *Accidente* Se presenta volcamiento de vehí...
# 1    1047809727118430210  Rt Av. Las villas norte al sur llegando a la 1...
# 2    1047843812977065985  Para peor tristeza, muerto en la Av. Cra. 30, ...
# 3    1047986702982234112  Rt Incidente vial entre taxi y bus en la carre...
# 4    1048014671943553024  Rt Se solicita tránsito choque en Av Américas ...
# ..                   ...                                                ...
# 667  1116330751061037057  colision entre buses  en la carrera 68 con cal...
# 668  1064851464584081408  colision entre dos particulares ‍ en la Carrer...
# 669  1064847130840453120  colision entre dos particulares en la Carrera ...
# 670  1093845140983218184  CRA 80 X CL 45 SUR : Se presenta incidente via...
# 671   979318808136560641  Carrera 91 calle 95 lesionado en accidente de ...
#
#               created_at        user_name     user_location  \
# 0     2018-10-04 6:23:50  camilogallardoa               NaN
# 1     2018-10-04 6:24:40  camilogallardoa               NaN
# 2     2018-10-04 8:40:07          capdiaz  Bogotá, Colombia
# 3    2018-10-04 18:07:55  camilogallardoa               NaN
# 4    2018-10-04 19:59:03  camilogallardoa               NaN
# ..                   ...              ...               ...
# 667   2019-04-11 8:22:46      RedapBogota  Bogota, Colombia
# 668   2018-11-20 7:02:27      RedapBogota  Bogota, Colombia
# 669   2018-11-20 6:45:14      RedapBogota  Bogota, Colombia
# 670   2019-02-08 7:12:58      RedapBogota  Bogota, Colombia
# 671   2018-03-29 6:26:13      RedapBogota  Bogota, Colombia
#
#                      source  \
# 0             Search BOGOTA
# 1             Search BOGOTA
# 2             Search BOGOTA
# 3             Search BOGOTA
# 4             Search BOGOTA
# ..                      ...
# 667  4_SEARCH TIMELINE USER
# 668  4_SEARCH TIMELINE USER
# 669  4_SEARCH TIMELINE USER
# 670  4_SEARCH TIMELINE USER
# 671  4_SEARCH TIMELINE USER
#
#                                                  clean  \
# 0    Rt *Accidente* Se presenta volcamiento de vehí...
# 1    Rt Av. Las villas norte al sur llegando a la 1...
# 2    Para peor tristeza, muerto en la Av. Cra. 30, ...
# 3    Rt Incidente vial entre taxi y bus en la carre...
# 4    Rt Se solicita tránsito choque en Av Américas ...
# ..                                                 ...
# 667  colision entre buses en la carrera 68 con call...
# 668  colision entre dos particulares en la Carrera ...
# 669  colision entre dos particulares en la Carrera ...
# 670  CRA 80 X CL 45 SUR : Se presenta incidente via...
# 671  Carrera 91 calle 95 lesionado en accidente de ...
#
#                                               entities  \
# 0              [(carrera 68 con la Av Esperanza, loc)]
# 1    [(Av. Las villas, loc), (la 127, loc), (buleva...
# 2               [(Av. Cra . 30, loc), (Calle 67, loc)]
# 3                 [(carrera 10 con calle 27 sur, loc)]
# 4    [(Av Américas, loc), (puente Av boyaca, loc), ...
# ..                                                 ...
# 667                   [(carrera 68 con calle 13, loc)]
# 668               [(Carrera 68 con Av Esperanza, loc)]
# 669                   [(Carrera 9 con calle 187, loc)]
# 670                        [(CRA 80 X CL 45 SUR, loc)]
# 671                       [(Carrera 91 calle 95, loc)]
#
#                                    location  \
# 0            carrera 68 con la Av Esperanza
# 1        Av. Las villas la 127 bulevar Niza
# 2                     Av. Cra . 30 Calle 67
# 3               carrera 10 con calle 27 sur
# 4    Av Américas puente Av boyaca Av boyaca
# ..                                      ...
# 667                 carrera 68 con calle 13
# 668             Carrera 68 con Av Esperanza
# 669                 Carrera 9 con calle 187
# 670                      CRA 80 X CL 45 SUR
# 671                     Carrera 91 calle 95
#
#                                  address_normalization  \
# 0    BOGOTA AVENIDA CARRERA 68 LA AVENIDA DE LA ESP...
# 1        BOGOTA AVENIDA LAS VILLAS LA 127 BULEVAR NIZA
# 2                   BOGOTA AVENIDA CARRERA 30 CALLE 67
# 3                       BOGOTA CARRERA 10 CALLE 27 SUR
# 4    BOGOTA AVENIDA DE LAS AMERICAS PUENTE AVENIDA ...
# ..                                                 ...
# 667         BOGOTA AVENIDA CARRERA 68 AVENIDA CALLE 13
# 668  BOGOTA AVENIDA CARRERA 68 AVENIDA DE LA ESPERANZA
# 669                 BOGOTA AVENIDA CARRERA 9 CALLE 187
# 670     BOGOTA AVENIDA CARRERA 80 AVENIDA CALLE 45 SUR
# 671                 BOGOTA AVENIDA CARRERA 91 CALLE 95
#
#                                                   gmap
# 0    {'lat': 4.634422233333333, 'lng': -74.09608436...
# 1        {'lat': 4.7115524, 'lng': -74.07254429999998}
# 2    {'lat': 4.660691244444443, 'lng': -74.07480312...
# 3    {'lat': 4.569560044444444, 'lng': -74.09424587...
# 4                    {'lat': 4.63044, 'lng': -74.1378}
# ..                                                 ...
# 667  {'lat': 4.653370466666667, 'lng': -74.10372093...
# 668  {'lat': 4.634422233333333, 'lng': -74.09608436...
# 669  {'lat': 4.761263911111112, 'lng': -74.03132992...
# 670            {'lat': 4.6032374, 'lng': -74.15371445}
# 671  {'lat': 4.721292066666667, 'lng': -74.09197183...
#
# [672 rows x 11 columns]

# %%
geocoding.to_csv(dir_+"ner_dataset_norm_geocoding.tsv",sep='\t')
