# %% [markdown]
# # Address Normalization
# ### By **Néstor Suat** in 2021
#
# **Descripción:** Normalización de direcciones usando librería en C `libpostal`
#
# Fuente: https://github.com/openvenues/libpostal

# %%
from postal.expand import expand_address
import pandas as pd

# %%
## Variables para importar modelos y demás
dir_ = "../../data/v1/NER/"

file = 'tweets_location.tsv' # Dataset

## Importando Dataset
dataset = pd.read_csv(dir_+file, delimiter = "\t", quoting = 3)

# %%
aux = [1]
aux2 = [2,3,4]
aux+aux2
# Out:
# [1, 2, 3, 4]

# %%
locations = []
for i in range(len(dataset)):    
    loc = []
    text = dataset.iloc[i]['location']
    loc.append(text)
    expansions = expand_address(text, 
                                roman_numerals=False, 
                                split_alpha_from_numeric=True, 
                                expand_numex=False,
                                languages=["es"])
    
    loc = loc + [len(expansions)] + expansions
    locations.append(loc)

# %%
df = pd.DataFrame(locations)
df.rename(columns={0:'original',1:'total'}, inplace=True)
df
# Out:
#                                      original  total  \
# 0     Avenida Primero de Mayo sena carrera 30      1
# 1              carrera 68 con la Av Esperanza      2
# 2          Av. Las villas la 127 bulevar Niza      2
# 3                        Av. NQS con calle 67      2
# 4                       Av. Cra . 30 Calle 67      1
# ...                                       ...    ...
# 1331                          Cra 7 calle 134      1
# 1332                          Cra 7 calle 140      1
# 1333                       CRA 80 X CL 45 SUR      3
# 1334                      Carrera 91 calle 95      1
# 1335                     Carrera 9a con 135 C      6
#
#                                                  2  \
# 0          avenida primero de mayo sena carrera 30
# 1        carrera 68 con la avenida calle esperanza
# 2     avenida calle las villas la 127 bulevar niza
# 3                   avenida calle nqs con calle 67
# 4                      avenida carrera 30 calle 67
# ...                                            ...
# 1331                           carrera 7 calle 134
# 1332                           carrera 7 calle 140
# 1333                      carrera 80 con cl 45 sur
# 1334                           carrera 91 calle 95
# 1335                          carrera 9a con 135 c
#
#                                            3                            4  \
# 0                                       None                         None
# 1        carrera 68 con la avenida esperanza                         None
# 2     avenida las villas la 127 bulevar niza                         None
# 3                   avenida nqs con calle 67                         None
# 4                                       None                         None
# ...                                      ...                          ...
# 1331                                    None                         None
# 1332                                    None                         None
# 1333            carrera 80 con colima 45 sur  carrera 80 con calle 45 sur
# 1334                                    None                         None
# 1335                carrera 9a con 135 calle        carrera 9 a con 135 c
#
#                               5                    6                        7  \
# 0                          None                 None                     None
# 1                          None                 None                     None
# 2                          None                 None                     None
# 3                          None                 None                     None
# 4                          None                 None                     None
# ...                         ...                  ...                      ...
# 1331                       None                 None                     None
# 1332                       None                 None                     None
# 1333                       None                 None                     None
# 1334                       None                 None                     None
# 1335  carrera 9 a con 135 calle  carrera 9 con 135 c  carrera 9 con 135 calle
#
#          8     9  ...    19    20    21    22    23    24    25    26    27  \
# 0     None  None  ...  None  None  None  None  None  None  None  None  None
# 1     None  None  ...  None  None  None  None  None  None  None  None  None
# 2     None  None  ...  None  None  None  None  None  None  None  None  None
# 3     None  None  ...  None  None  None  None  None  None  None  None  None
# 4     None  None  ...  None  None  None  None  None  None  None  None  None
# ...    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1331  None  None  ...  None  None  None  None  None  None  None  None  None
# 1332  None  None  ...  None  None  None  None  None  None  None  None  None
# 1333  None  None  ...  None  None  None  None  None  None  None  None  None
# 1334  None  None  ...  None  None  None  None  None  None  None  None  None
# 1335  None  None  ...  None  None  None  None  None  None  None  None  None
#
#         28
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 1331  None
# 1332  None
# 1333  None
# 1334  None
# 1335  None
#
# [1336 rows x 29 columns]

# %%
df.to_csv(dir_+"tweets_location_libpostal.tsv",sep='\t', index=False)
