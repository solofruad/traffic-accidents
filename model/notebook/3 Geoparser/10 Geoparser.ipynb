# %% [markdown]
# # Geoparser with Address Normalization
# ### By **Néstor Suat** in 2021
#
# **Descripción:** Combinando `9 Agregando location` y `9 Address Normalization`.
# Se realiza normalización de direcciones usando librería en C `libpostal`
#
# Fuente: https://github.com/openvenues/libpostal

# %%
from postal.expand import expand_address
from ast import literal_eval

import pandas as pd
import re
import math

# %%
def add_location(entities):
    loc = [ t for (t,l) in entities  if l == 'loc' ]
    loc = ' '.join(loc)
    return loc

def address_normalization(location):    
    expansions = expand_address(location, 
                                roman_numerals=False, 
                                split_alpha_from_numeric=True, 
                                expand_numex=False,
                                languages=["es"])
    expansions = re.sub(r'\b(\w+)( \1\b)+', r'\1', expansions[-1])
    return expansions

# %% [markdown]
# ### Importando dataset

# %%
## Variables para importar modelos y demás
dir_ = "../../data/v1/NER/src/prueba_bad_location/"

file = 'ner_dataset_test_bad.tsv' # Dataset

# %%
## Importando Dataset
dataset = pd.read_csv(dir_+file, delimiter = "\t", quoting = 3)
dataset.entities = dataset.entities.apply(literal_eval)
del dataset['Unnamed: 0']
del dataset['gmap']
print(dataset.shape)
dataset.head(5)
# Out:
# (16, 4)
#               id_tweet                                               text  \
# 0  1058331896298520576  Un muerto y cuatro heridos en Fatal accidente ...
# 1  1060077229043052545  @NoticiasCaracol accidente en la kr 10 con cl ...
# 2  1099689733956034561  @Citytv anoche ocurrió un accidente en frente ...
# 3  1125722482059763713  Av circunvalar con calle 53 accidente de dos m...
# 4  1131707280767033344  #MovilidadBogotá  #acueducto #Trancón  #Accide...
#
#             created_at                                           entities
# 0   2018-11-02 7:16:01                 [(avenida Boyacá con 71 sur, loc)]
# 1   2018-11-07 2:51:21  [(kr 10 con cl 1 c, loc), (estacion de TM del ...
# 2  2019-02-24 10:17:18  [(universidad nacional, loc), (puente, loc), (...
# 3   2019-05-07 6:22:09               [(Av circunvalar con calle 53, loc)]
# 4  2019-05-23 18:43:36  [(3 horas, time), (la calera, loc), (circunval...

# %%
dataset['location'] = dataset.entities.apply(add_location)
dataset['location']
# Out:
# 0                           avenida Boyacá con 71 sur
# 1     kr 10 con cl 1 c estacion de TM del policaparpa
# 2     universidad nacional puente crr 30 con calle 45
# 3                         Av circunvalar con calle 53
# 4                        la calera circunvalar con 85
# 5                                      cll 80 Siberia
# 6                       autopista norte con calle 153
# 7                                Calle 13 con Cra 104
# 8                                     Americas por 50
# 9                                  Carrera 20 por 140
# 10                                  Carrera 30 por 53
# 11                                  Av. Boyacá por 11
# 12                                    calle 63 Por 24
# 13                                              la 80
# 14                           avenida NQS con calle 19
# 15                   CALI X 15 FRIGORIFICO SAN MARTIN
# Name: location, dtype: object

# %% [markdown]
# ## Addresss Normalization
# * Usando librería en C `libpostal`

# %%
dataset['address_normalization'] = dataset.location.apply(address_normalization)
dataset['address_normalization']
# Out:
# 0                             avenida boyaca con 71 sur
# 1     carrera 10 con calle 1 c estacion de transmile...
# 2     universidad nacional puente carrera 30 con cal...
# 3              avenida circunvalar con avenida calle 53
# 4                  la calera avenida circunvalar con 85
# 5                              avenida calle 80 siberia
# 6                 autopista norte con avenida calle 153
# 7              avenida calle 13 con avenida carrera 104
# 8                        avenida de las americas por 50
# 9                                    carrera 20 por 140
# 10                            avenida carrera 30 por 53
# 11                                avenida boyaca por 11
# 12                              avenida calle 63 por 24
# 13                                     avenida calle 80
# 14                     avenida nqs con avenida calle 19
# 15    avenida ciudad de cali con 15 frigorifico san ...
# Name: address_normalization, dtype: object

# %%
dataset.to_csv(dir_+"ner_dataset_test_bad_norm.tsv",sep='\t')

# %% [markdown]
# ### Generando para Geocoding

# %%
locations = []
for i in range(len(dataset)):
    loc = []
    norm = 'Bogotá '+dataset.iloc[i]['address_normalization']
    loc += [norm] + ['CO']
    locations.append(loc)
locations
# Out:
# [['Bogotá avenida boyaca con 71 sur', 'CO'],
#  ['Bogotá carrera 10 con calle 1 c estacion de transmilenio del policaparpa',
#   'CO'],
#  ['Bogotá universidad nacional puente carrera 30 con calle 45', 'CO'],
#  ['Bogotá avenida circunvalar con avenida calle 53', 'CO'],
#  ['Bogotá la calera avenida circunvalar con 85', 'CO'],
#  ['Bogotá avenida calle 80 siberia', 'CO'],
#  ['Bogotá autopista norte con avenida calle 153', 'CO'],
#  ['Bogotá avenida calle 13 con avenida carrera 104', 'CO'],
#  ['Bogotá avenida de las americas por 50', 'CO'],
#  ['Bogotá carrera 20 por 140', 'CO'],
#  ['Bogotá avenida carrera 30 por 53', 'CO'],
#  ['Bogotá avenida boyaca por 11', 'CO'],
#  ['Bogotá avenida calle 63 por 24', 'CO'],
#  ['Bogotá avenida calle 80', 'CO'],
#  ['Bogotá avenida nqs con avenida calle 19', 'CO'],
#  ['Bogotá avenida ciudad de cali con 15 frigorifico san martin', 'CO']]

# %%
df = pd.DataFrame(locations,columns=['address','iso2'])
#df.rename(columns={0:'address',1:''}, inplace=True)
df
# Out:
#                                               address iso2
# 0                    Bogotá avenida boyaca con 71 sur   CO
# 1   Bogotá carrera 10 con calle 1 c estacion de tr...   CO
# 2   Bogotá universidad nacional puente carrera 30 ...   CO
# 3     Bogotá avenida circunvalar con avenida calle 53   CO
# 4         Bogotá la calera avenida circunvalar con 85   CO
# 5                     Bogotá avenida calle 80 siberia   CO
# 6        Bogotá autopista norte con avenida calle 153   CO
# 7     Bogotá avenida calle 13 con avenida carrera 104   CO
# 8               Bogotá avenida de las americas por 50   CO
# 9                           Bogotá carrera 20 por 140   CO
# 10                   Bogotá avenida carrera 30 por 53   CO
# 11                       Bogotá avenida boyaca por 11   CO
# 12                     Bogotá avenida calle 63 por 24   CO
# 13                            Bogotá avenida calle 80   CO
# 14            Bogotá avenida nqs con avenida calle 19   CO
# 15  Bogotá avenida ciudad de cali con 15 frigorifi...   CO

# %%
df.to_csv(dir_+"ner_dataset_test_bad_norm_format.csv", index=False)

# %% [markdown]
# ## Formateando resultados de Batch Geocode con Addresss Normalization

# %%
batch_geocode = pd.read_csv(dir_+'geocode_results_2021_03_08.csv')
batch_geocode = batch_geocode[['best_lat','best_long']]
batch_geocode
# Out:
#     best_lat  best_long
# 0   4.546440 -74.137025
# 1        NaN        NaN
# 2   4.638194 -74.084046
# 3   4.675313 -74.109147
# 4   4.617212 -74.061498
# 5   4.735036 -74.131319
# 6   4.742830 -74.048192
# 7   4.671054 -74.151988
# 8   4.625684 -74.108363
# 9        NaN        NaN
# 10  4.608336 -74.097021
# 11  4.651376 -74.126289
# 12  4.670706 -74.100837
# 13       NaN        NaN
# 14  4.604981 -74.070724
# 15  4.679109 -74.160104

# %%
dataset['gmap'] = ''
for i in range(len(dataset)):
    if(not math.isnan(batch_geocode.iloc[i]['best_lat'])):
        dataset.at[i,'gmap'] = "{'lat': "+str(batch_geocode.iloc[i]['best_lat'])+", 'lng': "+str(batch_geocode.iloc[i]['best_long'])+"}"
    else:
        dataset.drop(index=dataset.index[[i]])

# %%
geocoding = dataset.copy()
geocoding
# Out:
#                id_tweet                                               text  \
# 0   1058331896298520576  Un muerto y cuatro heridos en Fatal accidente ...
# 1   1060077229043052545  @NoticiasCaracol accidente en la kr 10 con cl ...
# 2   1099689733956034561  @Citytv anoche ocurrió un accidente en frente ...
# 3   1125722482059763713  Av circunvalar con calle 53 accidente de dos m...
# 4   1131707280767033344  #MovilidadBogotá  #acueducto #Trancón  #Accide...
# 5   1147555712521908225  @InviasOficial ,@numeral767 ,@BogotaseMueve . ...
# 6   1149638960328478721  #AEstaHora Colapsada autopista norte con calle...
# 7   1060683217383182338  @SectorMovilidad choque simple de tractomula c...
# 8    761823976700121088  Americas por 50, volcamiento de bus del sitp, ...
# 9    770763722210045956  Carrera 20 por 140 volcamiento de un vehículo ...
# 10   873824438684311552  Carrera 30 por 53 choque entre dos vehículos d...
# 11  1099717090376728577  En la Av. Boyacá por 11 se presentó una colisi...
# 12  1066203076254679040  En la calle 63 Por 24 se presenta un accidente...
# 13  1074991662848446464  @JotaVolatil Una tractomula se llevó a un moto...
# 14  1092759433795522560  *Accidentes con lesiones *Por la avenida NQS c...
# 15  1011937096179896320  CALI X 15 S-N (FRENTE A FRIGORIFICO SAN MARTIN...
#
#              created_at                                           entities  \
# 0    2018-11-02 7:16:01                 [(avenida Boyacá con 71 sur, loc)]
# 1    2018-11-07 2:51:21  [(kr 10 con cl 1 c, loc), (estacion de TM del ...
# 2   2019-02-24 10:17:18  [(universidad nacional, loc), (puente, loc), (...
# 3    2019-05-07 6:22:09               [(Av circunvalar con calle 53, loc)]
# 4   2019-05-23 18:43:36  [(3 horas, time), (la calera, loc), (circunval...
# 5   2019-07-06 12:19:37                    [(cll 80, loc), (Siberia, loc)]
# 6    2019-07-12 6:17:42             [(autopista norte con calle 153, loc)]
# 7   2018-11-08 18:59:20                      [(Calle 13 con Cra 104, loc)]
# 8    2016-08-06 2:19:24                           [(Americas por 50, loc)]
# 9   2016-08-30 18:22:46                        [(Carrera 20 por 140, loc)]
# 10   2017-06-11 3:49:15                         [(Carrera 30 por 53, loc)]
# 11  2019-02-24 12:06:00                         [(Av. Boyacá por 11, loc)]
# 12   2018-11-24 0:33:17                           [(calle 63 Por 24, loc)]
# 13   2018-12-18 6:35:59                                     [(la 80, loc)]
# 14   2019-02-05 7:18:46                  [(avenida NQS con calle 19, loc)]
# 15   2018-06-27 6:39:39  [(CALI X 15, loc), (FRIGORIFICO SAN MARTIN, loc)]
#
#                                            location  \
# 0                         avenida Boyacá con 71 sur
# 1   kr 10 con cl 1 c estacion de TM del policaparpa
# 2   universidad nacional puente crr 30 con calle 45
# 3                       Av circunvalar con calle 53
# 4                      la calera circunvalar con 85
# 5                                    cll 80 Siberia
# 6                     autopista norte con calle 153
# 7                              Calle 13 con Cra 104
# 8                                   Americas por 50
# 9                                Carrera 20 por 140
# 10                                Carrera 30 por 53
# 11                                Av. Boyacá por 11
# 12                                  calle 63 Por 24
# 13                                            la 80
# 14                         avenida NQS con calle 19
# 15                 CALI X 15 FRIGORIFICO SAN MARTIN
#
#                                 address_normalization  \
# 0                           avenida boyaca con 71 sur
# 1   carrera 10 con calle 1 c estacion de transmile...
# 2   universidad nacional puente carrera 30 con cal...
# 3            avenida circunvalar con avenida calle 53
# 4                la calera avenida circunvalar con 85
# 5                            avenida calle 80 siberia
# 6               autopista norte con avenida calle 153
# 7            avenida calle 13 con avenida carrera 104
# 8                      avenida de las americas por 50
# 9                                  carrera 20 por 140
# 10                          avenida carrera 30 por 53
# 11                              avenida boyaca por 11
# 12                            avenida calle 63 por 24
# 13                                   avenida calle 80
# 14                   avenida nqs con avenida calle 19
# 15  avenida ciudad de cali con 15 frigorifico san ...
#
#                                                  gmap
# 0   {'lat': 4.546440400000002, 'lng': -74.13702470...
# 1
# 2       {'lat': 4.6381938, 'lng': -74.08404639999998}
# 3                {'lat': 4.675313, 'lng': -74.109147}
# 4    {'lat': 4.6172124000000005, 'lng': -74.06149835}
# 5            {'lat': 4.73503645, 'lng': -74.13131915}
# 6     {'lat': 4.7428300000000005, 'lng': -74.0481921}
# 7     {'lat': 4.6710544999999986, 'lng': -74.1519878}
# 8      {'lat': 4.625684099999999, 'lng': -74.1083629}
# 9
# 10     {'lat': 4.608336299999999, 'lng': -74.0970212}
# 11             {'lat': 4.6513764, 'lng': -74.1262885}
# 12  {'lat': 4.670706449999999, 'lng': -74.10083709...
# 13
# 14     {'lat': 4.604981400000001, 'lng': -74.0707237}
# 15     {'lat': 4.679108599999999, 'lng': -74.1601036}

# %%
geocoding = geocoding[dataset['gmap']!='']
geocoding = geocoding.reset_index(drop=True)
geocoding
# Out:
#                id_tweet                                               text  \
# 0   1058331896298520576  Un muerto y cuatro heridos en Fatal accidente ...
# 1   1099689733956034561  @Citytv anoche ocurrió un accidente en frente ...
# 2   1125722482059763713  Av circunvalar con calle 53 accidente de dos m...
# 3   1131707280767033344  #MovilidadBogotá  #acueducto #Trancón  #Accide...
# 4   1147555712521908225  @InviasOficial ,@numeral767 ,@BogotaseMueve . ...
# 5   1149638960328478721  #AEstaHora Colapsada autopista norte con calle...
# 6   1060683217383182338  @SectorMovilidad choque simple de tractomula c...
# 7    761823976700121088  Americas por 50, volcamiento de bus del sitp, ...
# 8    873824438684311552  Carrera 30 por 53 choque entre dos vehículos d...
# 9   1099717090376728577  En la Av. Boyacá por 11 se presentó una colisi...
# 10  1066203076254679040  En la calle 63 Por 24 se presenta un accidente...
# 11  1092759433795522560  *Accidentes con lesiones *Por la avenida NQS c...
# 12  1011937096179896320  CALI X 15 S-N (FRENTE A FRIGORIFICO SAN MARTIN...
#
#              created_at                                           entities  \
# 0    2018-11-02 7:16:01                 [(avenida Boyacá con 71 sur, loc)]
# 1   2019-02-24 10:17:18  [(universidad nacional, loc), (puente, loc), (...
# 2    2019-05-07 6:22:09               [(Av circunvalar con calle 53, loc)]
# 3   2019-05-23 18:43:36  [(3 horas, time), (la calera, loc), (circunval...
# 4   2019-07-06 12:19:37                    [(cll 80, loc), (Siberia, loc)]
# 5    2019-07-12 6:17:42             [(autopista norte con calle 153, loc)]
# 6   2018-11-08 18:59:20                      [(Calle 13 con Cra 104, loc)]
# 7    2016-08-06 2:19:24                           [(Americas por 50, loc)]
# 8    2017-06-11 3:49:15                         [(Carrera 30 por 53, loc)]
# 9   2019-02-24 12:06:00                         [(Av. Boyacá por 11, loc)]
# 10   2018-11-24 0:33:17                           [(calle 63 Por 24, loc)]
# 11   2019-02-05 7:18:46                  [(avenida NQS con calle 19, loc)]
# 12   2018-06-27 6:39:39  [(CALI X 15, loc), (FRIGORIFICO SAN MARTIN, loc)]
#
#                                            location  \
# 0                         avenida Boyacá con 71 sur
# 1   universidad nacional puente crr 30 con calle 45
# 2                       Av circunvalar con calle 53
# 3                      la calera circunvalar con 85
# 4                                    cll 80 Siberia
# 5                     autopista norte con calle 153
# 6                              Calle 13 con Cra 104
# 7                                   Americas por 50
# 8                                 Carrera 30 por 53
# 9                                 Av. Boyacá por 11
# 10                                  calle 63 Por 24
# 11                         avenida NQS con calle 19
# 12                 CALI X 15 FRIGORIFICO SAN MARTIN
#
#                                 address_normalization  \
# 0                           avenida boyaca con 71 sur
# 1   universidad nacional puente carrera 30 con cal...
# 2            avenida circunvalar con avenida calle 53
# 3                la calera avenida circunvalar con 85
# 4                            avenida calle 80 siberia
# 5               autopista norte con avenida calle 153
# 6            avenida calle 13 con avenida carrera 104
# 7                      avenida de las americas por 50
# 8                           avenida carrera 30 por 53
# 9                               avenida boyaca por 11
# 10                            avenida calle 63 por 24
# 11                   avenida nqs con avenida calle 19
# 12  avenida ciudad de cali con 15 frigorifico san ...
#
#                                                  gmap
# 0   {'lat': 4.546440400000002, 'lng': -74.13702470...
# 1       {'lat': 4.6381938, 'lng': -74.08404639999998}
# 2                {'lat': 4.675313, 'lng': -74.109147}
# 3    {'lat': 4.6172124000000005, 'lng': -74.06149835}
# 4            {'lat': 4.73503645, 'lng': -74.13131915}
# 5     {'lat': 4.7428300000000005, 'lng': -74.0481921}
# 6     {'lat': 4.6710544999999986, 'lng': -74.1519878}
# 7      {'lat': 4.625684099999999, 'lng': -74.1083629}
# 8      {'lat': 4.608336299999999, 'lng': -74.0970212}
# 9              {'lat': 4.6513764, 'lng': -74.1262885}
# 10  {'lat': 4.670706449999999, 'lng': -74.10083709...
# 11     {'lat': 4.604981400000001, 'lng': -74.0707237}
# 12     {'lat': 4.679108599999999, 'lng': -74.1601036}

# %%
geocoding.to_csv(dir_+"ner_dataset_test_bad_norm_geocoding.tsv",sep='\t')
