# %% [markdown]
# # Creando Columnas lat y lon
# ### By **Néstor Suat** in 2021

# %%
import pandas as pd
from ast import literal_eval

# %%
dir_ = "../../data/v1/NER/"
file = 'ner_dataset_norm_geocoding.tsv' # Dataset
dataset = pd.read_csv(dir_+file, delimiter = "\t", quoting = 3)
dataset.gmap = dataset.gmap.apply(literal_eval)
del dataset['Unnamed: 0']
print(dataset.shape)
# Out:
# (672, 11)

# %%
dataset
# Out:
#                 id_tweet                                               text  \
# 0    1047809516937596928  Rt *Accidente* Se presenta volcamiento de vehí...
# 1    1047809727118430210  Rt Av. Las villas norte al sur llegando a la 1...
# 2    1047843812977065985  Para peor tristeza, muerto en la Av. Cra. 30, ...
# 3    1047986702982234112  Rt Incidente vial entre taxi y bus en la carre...
# 4    1048014671943553024  Rt Se solicita tránsito choque en Av Américas ...
# ..                   ...                                                ...
# 667  1116330751061037057  colision entre buses  en la carrera 68 con cal...
# 668  1064851464584081408  colision entre dos particulares ‍ en la Carrer...
# 669  1064847130840453120  colision entre dos particulares en la Carrera ...
# 670  1093845140983218184  CRA 80 X CL 45 SUR : Se presenta incidente via...
# 671   979318808136560641  Carrera 91 calle 95 lesionado en accidente de ...
#
#               created_at        user_name     user_location  \
# 0     2018-10-04 6:23:50  camilogallardoa               NaN
# 1     2018-10-04 6:24:40  camilogallardoa               NaN
# 2     2018-10-04 8:40:07          capdiaz  Bogotá, Colombia
# 3    2018-10-04 18:07:55  camilogallardoa               NaN
# 4    2018-10-04 19:59:03  camilogallardoa               NaN
# ..                   ...              ...               ...
# 667   2019-04-11 8:22:46      RedapBogota  Bogota, Colombia
# 668   2018-11-20 7:02:27      RedapBogota  Bogota, Colombia
# 669   2018-11-20 6:45:14      RedapBogota  Bogota, Colombia
# 670   2019-02-08 7:12:58      RedapBogota  Bogota, Colombia
# 671   2018-03-29 6:26:13      RedapBogota  Bogota, Colombia
#
#                      source  \
# 0             Search BOGOTA
# 1             Search BOGOTA
# 2             Search BOGOTA
# 3             Search BOGOTA
# 4             Search BOGOTA
# ..                      ...
# 667  4_SEARCH TIMELINE USER
# 668  4_SEARCH TIMELINE USER
# 669  4_SEARCH TIMELINE USER
# 670  4_SEARCH TIMELINE USER
# 671  4_SEARCH TIMELINE USER
#
#                                                  clean  \
# 0    Rt *Accidente* Se presenta volcamiento de vehí...
# 1    Rt Av. Las villas norte al sur llegando a la 1...
# 2    Para peor tristeza, muerto en la Av. Cra. 30, ...
# 3    Rt Incidente vial entre taxi y bus en la carre...
# 4    Rt Se solicita tránsito choque en Av Américas ...
# ..                                                 ...
# 667  colision entre buses en la carrera 68 con call...
# 668  colision entre dos particulares en la Carrera ...
# 669  colision entre dos particulares en la Carrera ...
# 670  CRA 80 X CL 45 SUR : Se presenta incidente via...
# 671  Carrera 91 calle 95 lesionado en accidente de ...
#
#                                               entities  \
# 0          [('carrera 68 con la Av Esperanza', 'loc')]
# 1    [('Av. Las villas', 'loc'), ('la 127', 'loc'),...
# 2       [('Av. Cra . 30', 'loc'), ('Calle 67', 'loc')]
# 3             [('carrera 10 con calle 27 sur', 'loc')]
# 4    [('Av Américas', 'loc'), ('puente Av boyaca', ...
# ..                                                 ...
# 667               [('carrera 68 con calle 13', 'loc')]
# 668           [('Carrera 68 con Av Esperanza', 'loc')]
# 669               [('Carrera 9 con calle 187', 'loc')]
# 670                    [('CRA 80 X CL 45 SUR', 'loc')]
# 671                   [('Carrera 91 calle 95', 'loc')]
#
#                                    location  \
# 0            carrera 68 con la Av Esperanza
# 1        Av. Las villas la 127 bulevar Niza
# 2                     Av. Cra . 30 Calle 67
# 3               carrera 10 con calle 27 sur
# 4    Av Américas puente Av boyaca Av boyaca
# ..                                      ...
# 667                 carrera 68 con calle 13
# 668             Carrera 68 con Av Esperanza
# 669                 Carrera 9 con calle 187
# 670                      CRA 80 X CL 45 SUR
# 671                     Carrera 91 calle 95
#
#                                  address_normalization  \
# 0    BOGOTA AVENIDA CARRERA 68 LA AVENIDA DE LA ESP...
# 1        BOGOTA AVENIDA LAS VILLAS LA 127 BULEVAR NIZA
# 2                   BOGOTA AVENIDA CARRERA 30 CALLE 67
# 3                       BOGOTA CARRERA 10 CALLE 27 SUR
# 4    BOGOTA AVENIDA DE LAS AMERICAS PUENTE AVENIDA ...
# ..                                                 ...
# 667         BOGOTA AVENIDA CARRERA 68 AVENIDA CALLE 13
# 668  BOGOTA AVENIDA CARRERA 68 AVENIDA DE LA ESPERANZA
# 669                 BOGOTA AVENIDA CARRERA 9 CALLE 187
# 670     BOGOTA AVENIDA CARRERA 80 AVENIDA CALLE 45 SUR
# 671                 BOGOTA AVENIDA CARRERA 91 CALLE 95
#
#                                                   gmap
# 0    {'lat': 4.634422233333333, 'lng': -74.09608436...
# 1        {'lat': 4.7115524, 'lng': -74.07254429999998}
# 2    {'lat': 4.660691244444443, 'lng': -74.07480312...
# 3    {'lat': 4.569560044444444, 'lng': -74.09424587...
# 4                    {'lat': 4.63044, 'lng': -74.1378}
# ..                                                 ...
# 667  {'lat': 4.653370466666667, 'lng': -74.10372093...
# 668  {'lat': 4.634422233333333, 'lng': -74.09608436...
# 669  {'lat': 4.761263911111112, 'lng': -74.03132992...
# 670            {'lat': 4.6032374, 'lng': -74.15371445}
# 671  {'lat': 4.721292066666667, 'lng': -74.09197183...
#
# [672 rows x 11 columns]

# %%
dataset['lat'] = ''
dataset['lon'] = ''
for i in range(len(dataset)):
    dataset.at[i,'lat'] = dataset.iloc[i]['gmap']['lat']
    dataset.at[i,'lon'] = dataset.iloc[i]['gmap']['lng']
dataset.head()
# Out:
#               id_tweet                                               text  \
# 0  1047809516937596928  Rt *Accidente* Se presenta volcamiento de vehí...
# 1  1047809727118430210  Rt Av. Las villas norte al sur llegando a la 1...
# 2  1047843812977065985  Para peor tristeza, muerto en la Av. Cra. 30, ...
# 3  1047986702982234112  Rt Incidente vial entre taxi y bus en la carre...
# 4  1048014671943553024  Rt Se solicita tránsito choque en Av Américas ...
#
#             created_at        user_name     user_location         source  \
# 0   2018-10-04 6:23:50  camilogallardoa               NaN  Search BOGOTA
# 1   2018-10-04 6:24:40  camilogallardoa               NaN  Search BOGOTA
# 2   2018-10-04 8:40:07          capdiaz  Bogotá, Colombia  Search BOGOTA
# 3  2018-10-04 18:07:55  camilogallardoa               NaN  Search BOGOTA
# 4  2018-10-04 19:59:03  camilogallardoa               NaN  Search BOGOTA
#
#                                                clean  \
# 0  Rt *Accidente* Se presenta volcamiento de vehí...
# 1  Rt Av. Las villas norte al sur llegando a la 1...
# 2  Para peor tristeza, muerto en la Av. Cra. 30, ...
# 3  Rt Incidente vial entre taxi y bus en la carre...
# 4  Rt Se solicita tránsito choque en Av Américas ...
#
#                                             entities  \
# 0        [('carrera 68 con la Av Esperanza', 'loc')]
# 1  [('Av. Las villas', 'loc'), ('la 127', 'loc'),...
# 2     [('Av. Cra . 30', 'loc'), ('Calle 67', 'loc')]
# 3           [('carrera 10 con calle 27 sur', 'loc')]
# 4  [('Av Américas', 'loc'), ('puente Av boyaca', ...
#
#                                  location  \
# 0          carrera 68 con la Av Esperanza
# 1      Av. Las villas la 127 bulevar Niza
# 2                   Av. Cra . 30 Calle 67
# 3             carrera 10 con calle 27 sur
# 4  Av Américas puente Av boyaca Av boyaca
#
#                                address_normalization  \
# 0  BOGOTA AVENIDA CARRERA 68 LA AVENIDA DE LA ESP...
# 1      BOGOTA AVENIDA LAS VILLAS LA 127 BULEVAR NIZA
# 2                 BOGOTA AVENIDA CARRERA 30 CALLE 67
# 3                     BOGOTA CARRERA 10 CALLE 27 SUR
# 4  BOGOTA AVENIDA DE LAS AMERICAS PUENTE AVENIDA ...
#
#                                                 gmap      lat      lon
# 0  {'lat': 4.634422233333333, 'lng': -74.09608436...  4.63442 -74.0961
# 1      {'lat': 4.7115524, 'lng': -74.07254429999998}  4.71155 -74.0725
# 2  {'lat': 4.660691244444443, 'lng': -74.07480312...  4.66069 -74.0748
# 3  {'lat': 4.569560044444444, 'lng': -74.09424587...  4.56956 -74.0942
# 4                  {'lat': 4.63044, 'lng': -74.1378}  4.63044 -74.1378

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 13 columns):
# id_tweet                 672 non-null int64
# text                     672 non-null object
# created_at               672 non-null object
# user_name                672 non-null object
# user_location            596 non-null object
# source                   672 non-null object
# clean                    672 non-null object
# entities                 672 non-null object
# location                 672 non-null object
# address_normalization    672 non-null object
# gmap                     672 non-null object
# lat                      672 non-null object
# lon                      672 non-null object
# dtypes: int64(1), object(12)
# memory usage: 68.4+ KB

# %%
dataset.to_csv(dir_+"ner_dataset_norm_lat_lon.tsv",sep='\t')
